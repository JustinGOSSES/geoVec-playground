# %%
#import glove
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
#import nltk 
#nltk.download() 
#!pip install glove-python-binary  thanks to @Ironwolf on github [necessary on Windows]
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
lines=["Hello this is a tutorial on how to convert the word in an integer format", "this is a beautiful day","Jack is going to office"]
target_url='https://mer-env.s3-ap-southeast-2.amazonaws.com/ENV12248.pdf-textract-text.txt'
import urllib.request
data = urllib.request.urlopen(target_url)
lines = []
for line in data:    
    #print(line.decode('utf-8'))
    lines.append(line.decode('utf-8').lower().strip())

# %%
lines2 = lines.copy() #for if you want one later

# %%
stop_words=set(stopwords.words('english')) 
lines_without_stopwords=[] #stop words contain the set of stop words 
for line in lines: 
    splitline = line.split(' ')
    temp_line=[] 
    for word in splitline: 
        if word not in stop_words: 
            temp_line.append(word) 
            string=' ' 
    lines_without_stopwords.append(string.join(temp_line)) 
    
lines=lines_without_stopwords

# %%
print(len(lines))
lines
# Out:
# 240578
# ['imx',
#  'resources',
#  'combined annual report',
#  'mount woods jv project',
#  'period',
#  '1st february 2011 31st january 2012',
#  'el3729, el3730, el3830, el4446, el4706, el4649',
#  'holder/ operator:',
#  'imx resources ltd',
#  'level 2, 100 railway road',
#  'subiaco wa 6008',
#  'oz minerals ltd',
#  '170 greenhill road,',
#  'parkside sa 5063',
#  'lynch (imx), c rochat, damm harris',
#  '(oz)',
#  'tammi doyle yvette laubsch',
#  'march 2012',
#  'pirsa - (1 digital)',
#  'imx resources ltd - (1 digital, 1 hardcopy)',
#  'oz minerals ltd - (1 digital, 1 hardcopy)',
#  'report contents confidential. rights report contents (including, without limitation, rights confidential',
#  'information copy right works (including photographs, diagrams, charts, maps graphs) comprised report) remain property',
#  'imx resources ltd. part report information contained may disclosed person without consent imx',
#  'resources ltd. part report information contained may reproduced (including stored form),',
#  'transmitted, published used purpose without consent imx resources ltd.',
#  'licences:',
#  'authors:',
#  'compiled:',
#  'date:',
#  'distribution:',
#  '',
#  '',
#  'preface',
#  'mt woods project subject joint venture agreement imx',
#  'resources ltd ("imx") oz minerals ltd ("ozl") imx explores iron',
#  "ore ozl explores minerals. owing companies' separate",
#  'targeting strategies, exploration programmes run independently.',
#  'consideration following report presented two separate volumes',
#  'describing individual exploration programmes operated imx ozl.',
#  '',
#  'combined report table contents',
#  'imx',
#  'resources',
#  'volume 1: imx resources ltd',
#  '5.1.6 snaefell prospect geology & structure',
#  '6.0 summary rehabilitation activities',
#  'summary',
#  'key words',
#  'list figures',
#  'list tables',
#  'appendices',
#  '1.0 introduction',
#  '2.0 tenure',
#  '3.0 regional geology',
#  '4.0 previous exploration',
#  '5.0 current exploration (imx)',
#  '5.1 snaefell prospect',
#  '5.1.1 exploration drilling',
#  '5.1.2 qaqc',
#  '5.1.3 accreditation',
#  '5.1.4 analysis quality control',
#  '5.1.5 regiona geology',
#  '5.1.7 snaefell conclusions',
#  '5.2 tomahawk prospect',
#  '5.2.1 hole location',
#  '5.2.2 geological logging',
#  '5.2.3 sampling methodology',
#  '5.2.4 tomahawk dtr summary',
#  '5.2.5 environment',
#  '7.0 expenditure (imx costings)',
#  '8.0 bibliography',
#  'appendices',
#  '',
#  '',
#  'iii',
#  'iii',
#  'iv',
#  '5',
#  '8',
#  '9',
#  '10',
#  '14',
#  '14',
#  '15',
#  '19',
#  '19',
#  '19',
#  '19',
#  '20',
#  '21',
#  '22',
#  '23',
#  '23',
#  '24',
#  '25',
#  '26',
#  '27',
#  '32',
#  '33',
#  '34',
#  '',
#  'volume 2: oz minerals ltd',
#  '1 introduction',
#  '1.1 location',
#  '1.2 work area clearance',
#  '2 geophysics',
#  '2.1 ground gravity data collection',
#  '2.2 induced polarisation data collection',
#  '2.3 potential field data processing',
#  '2.4 ip data processing',
#  '3 regional exploration drilling',
#  '3.1 rouse',
#  '3.2 arapiles',
#  '3.3 shadwell',
#  '3.4 bumblebee',
#  '3.5 aquila',
#  '3.6 eccles',
#  '3.7 pocket knife',
#  '3.8 black hills south',
#  '3.9 copper knob',
#  '3.10 fyans',
#  '4 environment',
#  '5 work',
#  '6 references',
#  '6',
#  '7',
#  '7',
#  '8',
#  '8',
#  '21',
#  '25',
#  '36',
#  '37',
#  '38',
#  '10',
#  '12',
#  '13',
#  '13',
#  '16',
#  '18',
#  '23',
#  '27',
#  '32',
#  '33',
#  '35',
#  '39',
#  '',
#  'imx',
#  'resources',
#  'mount woods project',
#  'combined annual report',
#  'period',
#  '30th january 2011 29th january 2012',
#  'volume 1: imx exploration',
#  'annual report period 30th january 2011 29th january 2012',
#  'imx resources ltd',
#  '',
#  'summary',
#  "report describes exploration activities undertaken imx resource ltd ('imx') mount",
#  'woods project licences 30th january 2011 29th january 2012.',
#  'project located near coober pedy subject mt woods project amalgamated',
#  'expenditure agreement lodged pirsa.',
#  'april 2010, joint venture entered imx oz minerals ltd (ozl) imx',
#  'exploration licences mt woods project. result agreement, certain conditions,',
#  "ozl's interest became 51% jv duration jv. exception iron ore,",
#  'ozl operator manager exploration imx retains rights exploitable iron ore.',
#  'field activities imx reporting period included rc diamond drilling snaefell',
#  'magnetite iron ore prospect rc drilling tomahawk magnetite iron ore prospect drill',
#  'hole rehabilitation. summarised below.',
#  'tenement',
#  'el4649',
#  'el4706',
#  'total expenditure (imx) reporting period $2,665,542.74.',
#  'data files listed verification table appendix d.',
#  'key words',
#  'coober pedy, billa kalina 1:250,000 map sheets; proterozoic, mount woods inlier, snaefell,',
#  'tomahawk, cairn hill, iron oxide copper-gold geophysics, diamond drilling, rc drilling,',
#  'assaying, airborne gravity gradient, aeromagnetic survey, ip geophysics',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  'activity',
#  'rc holes',
#  'diamond drilling',
#  'rehabilitation',
#  'rc holes',
#  'holes',
#  'samples',
#  '32',
#  '2965',
#  '2',
#  '25',
#  '6',
#  '1010',
#  'metres',
#  '8201',
#  '310',
#  '1544',
#  'no.',
#  '137',
#  '',
#  'table contents',
#  'summary',
#  'key words',
#  'list figures',
#  'list tables',
#  'appendices',
#  '1.0 introduction',
#  '2.0 tenure',
#  '3.0 regional geology',
#  '4.0 previous exploration',
#  '5.0',
#  'current exploration (imx)',
#  '5.1 snaefell prospect',
#  '5.1.1 exploration drilling',
#  '5.1.2 qaqc',
#  '5.1.3 accreditation',
#  '5.1.4 analysis quality control',
#  '5.1.5 regional geology',
#  '5.1.6 snaefell prospect geology & structure',
#  '5.1.7 snaefell conclusions',
#  '5.2 tomahawk prospect',
#  '5.2.1 hole location',
#  '5.2.2 geological logging',
#  '5.2.3 sampling methodology',
#  '5.2.4 tomahawk dtr summary',
#  '5.2.5 environment',
#  '6.0',
#  'summary rehabilitation activities',
#  '7.0 expenditure (imx costings)',
#  '8.0 bibliography',
#  'appendices',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  '',
#  '',
#  'iv',
#  '5',
#  '8',
#  '9',
#  '14',
#  '15',
#  '19',
#  '19',
#  '19',
#  '19',
#  '20',
#  '22',
#  '23',
#  '23',
#  '24',
#  '25',
#  '26',
#  'iii',
#  'iii',
#  '10',
#  '14',
#  '21',
#  '27',
#  '32',
#  '33',
#  '34',
#  '',
#  'list figures',
#  'figure 1',
#  'location imx mt woods project licences',
#  'figure 2',
#  'exploration summary map',
#  'figure 3',
#  'location snaefell prospect',
#  'figure 4',
#  'plan view interpreted faults drill holes rtp 1st vertical',
#  'derivative magnetite image core area snaefell prospect.',
#  'figure 5',
#  'cross section showing structural information sfd003 503395me',
#  'figure 6',
#  'location drill holes tomahawk target rtp1vd magnetics',
#  'figure 7',
#  'section tomahawk target drill holes thrc001 002',
#  'figure 8',
#  'snaefell july 2011 sfd002 rehabilitation',
#  'figure 9',
#  'snaefell july 2011 sfd002 rehabilitation',
#  'figure 10',
#  'snaefell - collar sfrc014 rehabilitation',
#  'figure 11',
#  'snaefell - collar sfrco14 rehabilitation',
#  'figure 12',
#  'hole capped tomahawk preventing wildlife entering drill hole',
#  'list tables',
#  'table 1',
#  'tenure details',
#  'table 2',
#  '2009 exploration statistics',
#  'table 3',
#  '2010 exploration statistics',
#  'table 4',
#  '2011 exploration contractors consultants',
#  'table 5',
#  'summary elements analysed (snaefell)',
#  'table 6',
#  'summary elements analysed (tomahawk)',
#  'table 7',
#  'significant intervals tomahawk rc drilling',
#  'table 8',
#  'snaefell 2011 - locations rehabilitated sites',
#  'table 9',
#  'expenditure 30th january 2011 29th january 2012',
#  'table 10',
#  'expenditure 29th january 2011 29th january 2012',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  '',
#  'appendices',
#  '',
#  'resource estimation report',
#  'b',
#  'drilling data',
#  'c',
#  'metallurgy reports',
#  '',
#  'core photos (see government sa mineral resources website, drillhole database)',
#  'e',
#  'verification table',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  '',
#  '1.0 introduction',
#  'report (volume 1 2) details exploration work undertaken imx exploration',
#  'licences. includes el 4649 (kangaroo dam), el 4706 (mt woods), el 3729 (warrina north),',
#  'el 3730 (warrina south), el 3830 (mt brady), el 4446 (yarrabolina hill) reporting',
#  'period 30th january 2011 29th january 2012. location licences shown',
#  'figure 1.',
#  'exploration licence 4649 (kangaroo dam) located approximately 40km south-east coober',
#  'pedy covers area 484 square kilometres. imx resources hold 100% licence,',
#  'operations licence involve oz exploration pty ltd joint-venture agreement.',
#  'tenement start date 25/01/2011 due expire 23/03/2013. el 4649',
#  'contains current imx high priority prospect snaefell.',
#  'el 4706 (mt woods) located approximately 50km se coober pedy covers area',
#  '1620 square kilometres. imx resources hold 100% licence, operations licence',
#  'involve oz exploration pty ltd joint-venture agreement. mt woods tenement start date',
#  '24/03/2011 due expire 23/03/2013 el 4706 contains current imx high',
#  'priority target tomahawk.',
#  'el 3729 (warrina north located approximately 40 km north-east coober pedy covers',
#  'area 565 square kilometres. imx resources hold 100% licence, operations',
#  'licence involve oz exploration pty ltd joint-venture agreement. tenement start date',
#  '05/04/2007 due expire 04/04/2012. work completed',
#  'tenement imx resources current reporting period.',
#  'el 3730 (warrina south) located approximately 80km east coober pedy covers area',
#  '279 square kilometres. imx resources hold 100% licence, operations licence',
#  'involve oz exploration pty ltd joint-venture agreement. licence start date',
#  '05/04/2007 due expire 04/04/2012. work completed tenement',
#  'imx resources current reporting period.',
#  'el 3830 (mt brady) located approximately 35km south-east coober pedy covers area',
#  '62 square kilometres. imx resources hold 100% licence, operations license',
#  'involve oz exploration pty ltd joint-venture agreement. licence start date',
#  '10/07/2007 due expire 09/07/2012. work completed',
#  'tenement imx resources current reporting period.',
#  'el 4446 (yarrabolina hill) located approximately 140km se coober pedy covers area',
#  '80 square kilometres. imx resources hold 100% licence operation licence',
#  'involve oz exploration pty ltd joint-venture agreement. license start date',
#  '14/03/2010 expired 14/03/2012. subsequent replacement licence application',
#  'submitted early 2012, outcome pending.',
#  'exploration licences located northern gawler craton south australia. access via',
#  'sealed stuart highway via series dirt station tracks, many become',
#  'impassable wet weather. exploration licences situated mount penrhyn pastoral',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  '',
#  'lease within coober pedy (sh 53-06) 1:250,000 map sheet located within',
#  'woomera prohibited area.',
#  "main target areas 'snaefell' 'tomahawk' (figure 2) lie east stuart range edge",
#  'extensive undulating plains numerous gilgais (clay depressions) sandsheets.',
#  'locally gibber cover prospects.',
#  'imx lower priority targets lie western side stuart range,',
#  'formed eroding basement bulldog shale. eroded shale silcrete resulted',
#  'mixtures silcrete, gibber, grey shale variegated hard soft shale. soils consist',
#  'moderately deep (0.3-1.0 m) crusty red duplex soils minor silcrete outcrops, gilgais.',
#  'stuart range drainage divide separates east-draining creeks feed lake eyre',
#  'basin southwest-draining creeks drain towards great australian bight.',
#  '*boorthanna siding',
#  '6,825,000 mn',
#  '*mount',
#  'bulgaravhill',
#  '*box creek',
#  'woomera',
#  'prohibited',
#  'area',
#  '*pilehill',
#  'el3729',
#  '*deearay hill',
#  'carguaranorkacaano',
#  'el3730',
#  'kcooberpedy',
#  "*low'cl",
#  '*calt/',
#  '6,775,000 mn',
#  '*backadina- hill',
#  'el3730',
#  'ard rise',
#  '*morton rise',
#  'el3830',
#  'mount woods',
#  '*compeera hill',
#  'acodna',
#  'el4649',
#  '6,750,000 mn.',
#  '*mount penrhyn.',
#  'el4706',
#  'oned)',
#  '*mount purvis',
#  'w e',
#  'p r h 1: b f e',
#  '*moun',
#  '6,725.000 mn',
#  '*waresipeaf',
#  'aprom',
#  'el4446',
#  'aingomar',
#  'mount sandy',
#  '*se',
#  'figure 1: location imx mt woods project licences',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  '',
#  'el3729',
#  'snaefell',
#  'drilling',
#  'figure 2: exploration summary map showing location two high priority targets,',
#  'annual report period 30th january 2011 29th january 2012',
#  '6,900,000mbl',
#  '6.750. 50.000mn',
#  'snaefell tomahawk.',
#  'imx resources ltd',
#  'el3730n',
#  'el4706',
#  'coober pedy',
#  'el4649',
#  'rc diamond',
#  'el3730',
#  'exploration summary map',
#  'tfe 3830',
#  'tomahawk',
#  'rcdrilling',
#  'figure 2:',
#  'tenement',
#  'road',
#  'town',
#  'ktlometres',
#  'legend',
#  'el4446',
#  '',
#  '2.0 tenurf',
#  'april 2010, joint venture entered imx ozl imx els mt',
#  'woods project area. imx retains rights exploitable iron ore, ozl operator',
#  'manager exploration minerals except iron.',
#  'table 1 summarises tenure status mount woods exploration licences. although cairn',
#  'hill mining lease ml6303 51% imx resources owned located within el4706',
#  'boundary, part group reporting therefore described report.',
#  'table 1: tenure details',
#  'licence',
#  'el4649',
#  'kangaroo dam',
#  'el4706',
#  'mt woods',
#  'el 3729',
#  'warrina north',
#  'el 3730',
#  'warrina south',
#  'el 3830',
#  'mt brady',
#  'el 4446',
#  'yarrabolina hill',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  'granted',
#  'expiry',
#  '25 january 2011',
#  '23 march 2013',
#  '24 march 2011',
#  '23 march 2013',
#  '5 april 2007',
#  '4 april 2012',
#  '5 april 2007',
#  '4 april 2012',
#  '10 july 2007',
#  '9 july 2012',
#  '14 march 2010',
#  '14 march 2012',
#  'year',
#  '2',
#  '2',
#  '6',
#  '6',
#  '6',
#  '3',
#  'area',
#  '484 km 2',
#  '1620 km 2',
#  '565 km 2',
#  '279 km 2',
#  '62 km 2',
#  '80 km 2',
#  'status',
#  'current',
#  'current',
#  'current',
#  'current',
#  'current',
#  'current',
#  '',
#  '3.0 regional gfology',
#  'exploration licences cover part palaeoproterozoic mount woods inlier, tectonic block',
#  'variable magnetic intensity lying east southeast coober pedy ridge',
#  'mabe creek inlier. three terranes abut interpreted archaean cratonic area south',
#  'west. area contains major regional structures (including karari fault zone)',
#  'traversed several prominent northwest trending structures.',
#  'mount woods inlier comprises high grade (amphibolite granulite facies) palaeoproterozoic',
#  'quartzo-feldspathic gneisses, meta-iron formations, quartz-feldspar-biotite schists, quartzites, calc-',
#  'silicate rocks forsterite marbles. metamorphic complex intruded syn- post-',
#  'tectonic granitoids (e.g., balta granite, polyphase hiltaba-age granite comprising non-foliated',
#  'brick-red granite, porphyritic granite hybrid granite). metamorphics characterised',
#  'intense magnetic response regional aeromagnetic data, reflects combination',
#  'magnetite-rich precursor sediments, including bifs, magnetite alteration, interpreted mafic',
#  'intrusive bodies.',
#  'mount woods inlier poorly exposed. regionally, limited outcrops gneisses',
#  "granites southeast el's, gawler range volcanics archaean gneisses",
#  "south southwest mt woods area. basement outcrop within el's extremely",
#  'restricted small granite gneiss outcrop sparsely noted throughout tenements.',
#  'proterozoic basement overlain mesozoic tertiary sedimentary cover. north',
#  'permian tallaringa trough, cover thickness increases markedly. west, cover',
#  'thickness also increases due presence permian cambrian sedimentary rocks,',
#  'increased thickness mesozoic units. cover sequences comprise cretaceous sediments',
#  'cadna-owie formation, algebuckina sandstone bulldog shale, turn',
#  'overlain tertiary, ouaternary recent units. cover units thicken south tenement',
#  'phillipson trough.',
#  "within area el's, basement blanketed variable thicknesses tertiary",
#  'holocene sediments, significant thicknesses permian sediments, kangaroo',
#  'dam mt woods el area underlain dark grey shales interbedded, friable sandstone',
#  'units cretaceous bulldog shale.',
#  'deep weathering produced profile pallid zone clays, ferruginous mottled zone, siliceous',
#  'layers calcrete. layers opaline silica recognised locally. extensive workings opal',
#  "occur allan's rise nearby.",
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  '',
#  '4.0 previous fxploration',
#  'exploration iron ore coober pedy region undertaken delhi petroleum',
#  '1962-1965, extensive base precious metal exploration, minor uranium',
#  'diamond exploration, carried newmont ltd (1970-1977), cra exploration (1981-',
#  '1988), bhp minerals (1991-1995) wmc resources (1995-2000, joint venture bhp).',
#  'basement outcrop within tenement area, previous exploration',
#  'strongly reliant geophysical techniques. drilling (principally rotary mud percussion)',
#  'geophysical basement targets cover completed. extensive regiona rc drilling also',
#  'completed pirsa part south australian steel energy project phillipson',
#  'coober pedy 1:100,000 map sheets (1995).',
#  '1980s',
#  'crae explored area series els search stratiform base metals, diamonds,',
#  'iocg mineralisation. program first systematic detailed exploration area.',
#  "bulk work current area carried el1330 'leonard rise'.",
#  'crae initially flew aeromagnetic radiometric survey 500m line-spacing. however, little',
#  'work undertaken ground el4649.',
#  '1990s',
#  'bhp selected number targets coober pedy ridge project area. ground-based',
#  'magnetic surveys confirmed anomalies twenty drill-tested. bhp ranked three',
#  "targets 'economically interesting', none within area current",
#  'els.',
#  '1995, wmc managed joint venture bhp. wmc carried geochemical orientation',
#  'surveys, regional aeromagnetic gravity interpretations. detailed exploration selected',
#  'magnetic gravity targets consisted detailed gravity ip cetus, snaefell',
#  'aquila targets east el4649. mineralisation located els',
#  'relinquished jv.',
#  '2000-2003',
#  'goldstream mining nl (gdm) acquired ground 2000. 2001 2003, part',
#  'joint venture, anglo managed exploration, initially iron oxide copper-gold mineralisation.',
#  'work included ground em, magnetics gravity surveys, soil sampling, rc drilling (14 holes:',
#  'arc015-028), petrography anomalous pt+pd+au ni/cu mineralisation (max 435',
#  'ppb pd) noted basal portion arc025 associated pyrrhotite veinlets (brewer,',
#  "2004). locality subsequently called 'kangaroo dam prospect'.",
#  '2004-2007',
#  '2004 management licence returned gdm. single rc drillhole kdrc001',
#  'kangaroo dam prospect intersected 2 @ 1.78 g/t pd+pt+au within 18 interval assaying',
#  '0.53 g/t pd+pt+au 202 m. intersection associated geophysical feature extending',
#  'approximately twenty kilometres length interpreted meta-gabbro body (manzi,',
#  '2004).',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  '',
#  '2005 exploration included ground magnetic surveying drilling kdrc002.',
#  'samples anglo holes arc001 arc029 analysed pges, weakly',
#  'anomalous values obtained. previous wmc ip data cetus, snaefell aquila',
#  'targets acquired digital form pirsa reprocessed zonge engineering (manzi',
#  'garsed, 2005).',
#  'exploration 2006 consisted diamond drilling, rc drilling analysis including petrology',
#  'water sampling. part pace collaborative drilling project dpy2-35, five diamond drill holes',
#  'completed kangaroo dam pge prospect. results holes low,',
#  'exception kdd003, intersected 22 @ 0.91 ppm pge (pd +pt+au) 148',
#  'm,',
#  'including 2 @ 1.94 g/t pge 151 m, 6 @ 1.15 ppm pge 160 (manzi',
#  'garsed, 2006a)',
#  'also 2006, two six rc holes abandoned, two tested ground magnetic features',
#  'snaefell prospect, one hole tested anomaly 9, one tested uranium target. snaefell,',
#  'mwrco1o returned 92 intersection averaging 29.60% fe. mwrco11 returned 80',
#  'intersection 32.40% fe. holes ended magnetite mineralisation (manzi garsed,',
#  '2006b). anomaly 9, mwrco12 intersected 4 @ 0.74 g/t pd+pt+au 56 m. mwrco14',
#  'abandoned 52 failed reach target depth. mwrc009 intersected slightly',
#  'elevated gold values, groundwater samples returned anomalous uranium values.',
#  'mwrc013 failed penetrate cadna-owie formation abandoned 48 m.',
#  'scintillometer readings low (manzi garsed, 2006c).',
#  'exploration 2007 included 383.2 line km helicopter-borne magnetics survey (flown',
#  'mean height 20 lines spaced 100 apart), four rotary mud holes, three water bore holes,',
#  'rehabilitation activities. anomalous uranium signatures indicative proximal uranium',
#  'mineralisation detected. however, drilling confirmed presence palaeochannels,',
#  'significant thicknesses potential sedimentary host packages. three water-monitoring bores',
#  'drilled adjacent four rotary mud uranium exploration holes part regional groundwater',
#  'monitoring program associated cairn hill mine groundwater supply investigation.',
#  '2008',
#  'early 2008 gdm changed name imx resources ltd. 2008, exploration imx',
#  'directed largely developing cairn hill magnetite deposit adjoining el3518. ml6303',
#  'granted cairn hill.',
#  'kangaroo dam el, two 160 rc holes, mw015 mw016, drilled anomaly 9.',
#  'intersected magnetite-bearing amphibolite rocks beneath 50 cover',
#  'clay-rich saprolitic layer, neither intersected anomalous pge base metal geochemistry.',
#  '2009',
#  'table 2 summarises work completed 2009.',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  '',
#  'table 2: 2009 exploration statistics',
#  'activity',
#  'holes',
#  'rc holes',
#  '27',
#  'ip survey',
#  'ground gravity survey',
#  'rehabilitation',
#  '7',
#  'one n-s, time-domain, dipole-dipole ip survey line across aquila target obtained',
#  'chargeability anomaly -13 msec. ground gravity surveys undertaken snaefell',
#  'prospect aquila, fitzgerald dam kd23 targets, identifying coincident mag-gravity',
#  'anomalies each.',
#  'previously-acquired regional helicopter-borne magnetic data, recently acquired',
#  'gravity data modelled aid drill hole planning.',
#  'twelve rc holes completed snaefell, ten others aquila, kd20, kd23',
#  'fitzgerald dam targets.',
#  'snaefell, host sequence tightly (isoclinally?/chevron?) folded magnetite(-specu',
#  'hematite) gneiss unit. may represent highly metamorphosed (granulite facies) iron formation',
#  'inter-banded carbonate units. dip mineralisation uncertain. iron-mineralised',
#  'sequence appears truncated fault parallel e-w trend unit. drilling',
#  'tested centre coincident magnetic gravity anomaly, part eastern end',
#  'feature, successfully located wide zones -30% fe.',
#  'aquila complex target magnetic, gravity ip anomalies near intersection two',
#  'major regional ene- wnw-trending structures possible conduits mineralisation.',
#  'two three rc holes pre-collars possible diamond tails designed target upper',
#  'part ip chargeability anomalies. however, holes steepened may missed',
#  'main part target chargeability feature.',
#  'magnetic feature kd20 occurs western end magnetic ridge extending westwards',
#  'kangaroo dam. modelling interpretation suggested two, converging magnetic plates,',
#  'possibility mineralised dilation zone two plates. three rc holes tested feature',
#  'without success.',
#  'two rc holes partially drill-tested kd23, strongly magnetic feature. holes intersected',
#  'magnetite-rich gneisses 30-38% fe. second intersected intervals 5%',
#  'sulphides, ran 14 ppb au, 69 ppm co, 923 ppm cu, 117 ppm ni 336 ppm zn.',
#  'fitzgerald dam magnetic target lies ne-trending magnetic linear towards western',
#  'side kangaroo dam el. two rc holes intersected magnetite-bearing gneiss green',
#  'pyroxene-bearing calc-silicate gneiss. first hole intersected thick interval magnetite',
#  'gneiss, including 104 interval 40 averaged 32.5% fe.',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  'metres',
#  'stations',
#  '4303',
#  '1787',
#  'no.',
#  'samples',
#  '2810',
#  'line km',
#  '2.7',
#  '53',
#  '',
#  '',
#  '2010',
#  'table 3 summarises work completed 2010.',
#  'table 3: 2010 exploration statistics',
#  'activity',
#  'diamond drilling',
#  'rc holes',
#  'petrology',
#  'metallurgy',
#  'rehabilitation',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  'no.',
#  '1973',
#  '375',
#  '28',
#  '6',
#  'holes',
#  '1 + 2 tails',
#  '5',
#  '19',
#  'metres',
#  'stations',
#  '569.2',
#  '1150',
#  'line km',
#  'samples',
#  '',
#  '5.0 current exploration (imx)',
#  'exploration iron ore current reporting period focused two targets: snaefell,',
#  'tomahawk. table 4 lists work undertaken contractors engaged.',
#  'table 4: 2011 exploration contractors consultants',
#  'activity',
#  'diamond drilling',
#  'coughlan drilling',
#  'rc drilling',
#  'gorey cole drilling',
#  'rehabilitation',
#  'andy brockhoff',
#  'assaying',
#  'genalysis-intertek laboratories',
#  'metallurgy',
#  'magnetics & gravity modelling',
#  'geological consultant',
#  '5.1 snaefell prospect',
#  'snaefell prospect located ~55km southeast coober pedy, 3km east stuart',
#  'highway (figure 3). snaefell iron ore prospect comprising magnetite, specular hematite',
#  'earthy hematite. prospect important potential contain greater 500',
#  'mt 25-30% iron.',
#  'initial inferred resource estimate drilling carried july 2011 109mt @ 30.13% fe.',
#  'current resource model expected upgrade 300mt. resource estimation report',
#  'presented appendix a.',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  'contractorlconsultant',
#  '',
#  '6790000m',
#  '6780060m',
#  '6770000m',
#  '(6760000m',
#  '/6750000n',
#  '(x40000i',
#  '6730000mi',
#  'figure 3: location snaefell prospect.',
#  '5.1.1 exploration drilling',
#  'total 34 drill holes completed snaefell prospect 2011 including 2 diamond',
#  'holes 32 rc holes. drilling data, including collar location, downhole assays, geology',
#  'survey data, geological code list presented appendix b core photos presented',
#  'appendix d. see government sa mineral resources website, drillhole database',
#  'april 2011 four rc holes (sfrc020-023) drilled gain confidence resource',
#  'modelling. holes drilled south -60 stopped nominal downhole depth',
#  '230-232m give vertica depth 200m. drill line spacing generally 180m collars',
#  'spaced 90m along lines. drilling confirmed magnetite (-specular hematite-earthy',
#  'hematite) mineralisation average grade -30% iron continuous throughout',
#  'core area continues ne-trending eastern part prospect. two metallurgical',
#  'pq diamond holes (sfd002 & sfd003) targeting different mineralisation styles also drilled',
#  'april 2011. metallurgical results positive viewed sg data reports',
#  'appendix c.',
#  '29/08/2011 26/10/2011 31 rc holes totalling 7606m drilled gorey cole',
#  'drillers using truck mounted 685 schram 985 reverse circulation (rc) drill rig trailer',
#  'mounted compressor. hole spacing 90m line spacing 200m. holes',
#  'designed test continuation magnetite increase inferred resource east west',
#  'depth. drilling confirmed continuation magnetite along strike east west also',
#  'continuation depth. northeast end snaefell prospect, named',
#  'barrule, sequences >30% fe thick occur core area.',
#  'weathering depth increased north-east deposit around holes sfrc030 sfrc033',
#  '& sfrc043.',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  'dober pedy',
#  'snaefell',
#  'attn h)ll',
#  '',
#  '5.1.1.1 hole location',
#  'hole collar locations accurately surveyed imx surveyor trent cowan imx',
#  'resource/termite resources cairn hill mine site aid imx resources exploration',
#  'geologist lynch. trimble differential gps (dgps) used accuracy 30mm',
#  'relation base station.',
#  '5.1.1.2 downhole surveying',
#  'holes surveyed abim solutions pty ltd kalgoorlie using icefield downhole gyro',
#  'instrument. icefield gyro preferred instruments open holes',
#  'accommodate rougher treatment. memory gyro rather north-seeking instrument.',
#  "calibrated monthly abims 'standard' holes either kalgoorlie newman, wa.",
#  'hole, abims operator ran dummy probe hole find depth, depth',
#  'may blocked. gyro instrument lowered depth',
#  'directional data acquired instrument pulled up. tool stopped every 10m',
#  'azimuth dip recorded. azimuth collar hole entered zero shot.',
#  'top hole data down-loaded laptop. collar location hole',
#  'obtained abims dgps. holes blocked, dip used reflex',
#  'instrument taken drilling azimuth estimated using either gyro data taken',
#  'unblocked portion hole, last azimuth hole become blocked',
#  'copied bottom hole.',
#  '5.1.1.3 november-december 2011',
#  'holes surveyed abim solutions pty ltd kalgoorlie using liu-he north seeking gyro',
#  'generally open holes. instrument refitted internal rubber buffers open',
#  'hole conditions knock calibration. azimuth tolerance +/-0.5 degrees.',
#  'gyro procedure first lower dummy probe check blockages. north seaking gyro',
#  'lowered bottom hole readings taken gyro pulled gyro get',
#  'hung rough ground open hole, causing incorrect readings. gyro stopped every',
#  "10-20m azimuth dip recorded. gyro instrument's calibration checked periodically",
#  'abims test hole kalgoorlie.',
#  'holes blocked, dip used reflex instrument taken drilling',
#  'azimuth estimated using either gyro data taken unblocked portion hole,',
#  'last azimuth hole became blocked copied bottom hole.',
#  '5.1.1.4 2011 samples: sfrco20-023',
#  'previously sfrc004-019, individual one metre rc samples collected entire',
#  'hole numbered green plastic bags. samples split onsite, drilling, using',
#  'cyclone 25/75 cone splitter calico bags 1m intervals. composite samples taken',
#  '1m presplit bags (i.e., 25-split). again, snaefell bulk tonnage prospect,',
#  'complete hole two metres basement intercept sampled.',
#  'geologist estimated 20% magnetite/hematite, 2m composite sample',
#  'collected presplit calico bag. low (less 20% magnetite) unmineralised zones,',
#  'samples collected 4m composite. sub-samples split using spear',
#  'necessary previous experience weight magnetite samples resulted oversize',
#  'lab samples, resulted triple processing splitting lab. previously, duplicates,',
#  'blanks standards routinely inserted sampling sequence every 20 samples,',
#  'discretion geologist. duplicates collected single split sample was,',
#  'thoroughly mixed de-stratified, split two identical samples. duplicates',
#  'occurred composite sample, duplicate spear sample collected per normal composite',
#  'sampling',
#  'procedures.',
#  'september 2010 july 2011 cleaned quartz rich sand. sand sourced coober',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  '',
#  'standards',
#  'blank',
#  'used',
#  '',
#  'srfc004-sfrc023)',
#  '',
#  'snaefell',
#  '',
#  '(holes',
#  '',
#  'pedy council yards. sio2 97% fe less 1%. blanks laboratory certified',
#  'low values iron.',
#  'samples initially dried, split, pulverised -75 micron genalysis adelaide',
#  'sent perth analysed xrf standard iron ore suite 14 elements. elements',
#  'reported element oxide. elements analysed (and detection limits) follows:',
#  'fe (0.01%), sio2 (0.03%), al2o3 (0.02%), (0.01%), k2o (0.01%), mgo (0.02%), mno',
#  '(0.01%), na2o (0.02%) (0.002%), p (0.001%), tio2 (0.02%), cu (0.005%), v2o5 (0.01%), cr2o3',
#  '(0.004%). loi detection limit 0.01%.',
#  'sfd002-sfd003: po diameter diamond drill holes sfd002-sfd003 primarily drilled',
#  'metallurgy purposes. holes conventionally drilled cover sediments basement',
#  'intercept chips/muds logged site. core logged detail sampling intervals set',
#  'mineralisation abundances geology. 1/4 core cut lengthwise sampling',
#  '1m usually longest sample interval. quarter core used majority',
#  'core needed metalugical testing. samples cut pulverised -75 micron',
#  'genalysis wa. elements reported element oxide. elements analysed (and',
#  'detection limits) follows: fe (0.01%), sio2 (0.03%), al2o3 (0.02%), (0.01%), k2o',
#  '(0.01%), mgo (0.02%), mno (0.01%), nazo (0.02%) (0.002%), p (0.001%), tio2 (0.02%), cu',
#  '(0.005%), v2o5 (0.01%), cr2o3 (0.004%). loi detection limit 0.01%.',
#  '5.1.1.5 2011 august november samples: sfrc024-046',
#  'drill cuttings split onsite drilling using cyclone cone splitter. entire',
#  'hole individual one-metre rc samples collected numbered green plastic bags. 25/75',
#  'split collected calico bags cone splitter representing two-metre intervals. four-',
#  'metre composite samples taken two-metre presplit bags. again, snaefell',
#  'bulk tonnage prospect, complete hole two metres basement intercept',
#  'sampled. geologist estimated 20% magnetite/hematite, 2m composite',
#  'sample collected presplit calico bag. low (less 20% magnetite) unmineralised',
#  'zones, samples collected 4m composite. sub-samples split using spear',
#  'necessary previous experience weight magnetite samples resulted oversize',
#  'lab samples, resulted triple processing splitting lab. previously, duplicates,',
#  'blanks standards routinely inserted sampling sequence every 20 samples,',
#  'discretion geologist. duplicates collected single split sample was,',
#  'thoroughly mixed de-stratified, split two identical samples. duplicates',
#  'occurred composite sample, duplicate spear sample collected per normal composite',
#  'sampling procedures. blank standards used snaefell (holes srfc004-sfrc051)',
#  'september 2010 november 2011 cleaned quartz rich sand. sand sourced',
#  'coober pedy council yards. sio2 97% fe less 1%. blanks laboratory',
#  'certified low values iron (<1%).',
#  'samples initially dried, split, pulverised -75 micron genalysis adealide',
#  'sent perth analysed (elements analysed detection limits): fe (0.01%),',
#  'sio2 (0.03%), al2o3 (0.02%), (0.01%), k2o (0.01%), mgo (0.02%), mno (0.01%), nazo',
#  '(0.02%) (0.002%), p (0.001%), tio2 (0.02%), cu (0.005%), v2o5 (0.01%), cr2o3 (0.004%). loi',
#  'detection limit 0.01%.',
#  '5.1.1.6 2011 august november samples: sfrc046-051',
#  'drill cuttings split onsite drilling using cyclone riffle splitter. entire',
#  'hole individual one-metre rc samples collected numbered green plastic bags. 25/75',
#  'split collected calico bags cone splitter representing two-metre intervals. drillers set',
#  'cone splitter 2m sample cone splitter could sent lab without need',
#  'imx resources ltd',
#  'annual report period 30th january 2011 29th january 2012',
#  '',
#  'use spear reduce sample size. four-metre composite samples taken',
#  'two-metre presplit bags using spear.',
#  'again, snaefell bulk tonnage prospect, complete hole two metres',
#  'basement intercept sampled. geologist estimated 20%',
#  'magnetite/hematite, whole 2m composite collected presplit calico bag. low',
#  '(less 20% magnetite) unmineralised zones, samples collected 4m composite.',
#  'previously, duplicates, blanks standards routinely inserted sampling sequence',
#  'every 20 samples, discretion geologist. duplicates collected single split',
#  'sample was, thoroughly mixed de-stratified, split two identical samples.',
#  'duplicates occurred composite sample, duplicate spear sample collected per',
#  'normal composite sampling procedures.',
#  'blank standards used snaefell (holes srfc004-sfrc051) september 2010',
#  'november 2011 cleaned quartz rich sand. sand sourced coober pedy council',
#  'yards. sio2 97% fe less 1%. blanks laboratory certified',
#  'low values iron',
#  'samples initially dried, split, pulverised -75 micron genalysis adealide',
#  'sent perth analysed xrf standard iron ore suite 14 elements. elements',
#  'reported element oxide. elements analysed (and detection limits) shown',
#  'table 5.',
#  'table 5: summary elements analysed (snaefell)',
#  'elements',
#  'al',
#  'al203',
#  'cao',
#  'cr',
#  'cr203',
#  'cu',
#  'fe',
#  'k20',
#  'mg',
#  'mgo',
#  'mno',
#  'units',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  'detection',
#  '0.01',
#  '0.02',
#  '0.01',
#  '0.002',
#  '0.004',
#  '0.005',
#  '0.01',
#  '0.01',
#  '0.01',
#  '0.02',
#  '0.01',
#  'method',
#  'fb1/xrf',
#  'icalc',
#  'fb1/',
#  'fb1/',
#  'icalc',
#  'fb1/',
#  'fb1/',
#  'fb1/',
#  'fb1/',
#  'icalc',
#  'fb1/',
#  'xrf',
#  'xrf',
#  'xrf',
#  'xrf',
#  'xrf',
#  'xrf',
#  'xrf',
#  'elements',
#  'na20',
#  'p',
#  '',
#  'si',
#  'si02',
#  'ti',
#  'tio2',
#  'total',
#  'v',
#  'v205',
#  'loi-1000',
#  'units',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  '%',
#  'detection',
#  '0.02',
#  '0.001',
#  '0.001',
#  '0.01',
#  '0.03',
#  '0.01',
#  '0.02',
#  '0.01',
#  '0.005',
#  '0.01',
#  '0.01',
#  'method',
#  'icalc',
#  'fb1/',
#  'fb1/',
#  ...]

# %%
#import WordNet Lemmatizer from nltk 

wordnet_lemmatizer = WordNetLemmatizer() 
lines_with_lemmas=[] 

for line in lines:
    splitline = line.split(' ')
    temp_line=[] 
    for word in splitline: 
        if word.isalpha():
            if len(word) > 3:
                temp_line.append(wordnet_lemmatizer.lemmatize(word)) 
        string=' ' 
    if len(temp_line) > 0:
        lines_with_lemmas.append(string.join(temp_line)) 
        
lines=lines_with_lemmas

# %%
print(len(lines_with_lemmas))
lines_with_lemmas
# Out:
# 89709
# ['resource',
#  'combined annual report',
#  'mount wood project',
#  'period',
#  'february january',
#  'resource',
#  'level railway road',
#  'subiaco',
#  'mineral',
#  'greenhill',
#  'parkside',
#  'lynch damm harris',
#  'tammi doyle yvette laubsch',
#  'march',
#  'pirsa',
#  'resource',
#  'mineral',
#  'report content right report content without right confidential',
#  'information copy right work map comprised remain property',
#  'resource part report information contained disclosed person without consent',
#  'resource part report information contained reproduced stored',
#  'published used purpose without consent resource',
#  'preface',
#  'wood project subject joint venture agreement',
#  'resource mineral explores iron',
#  'explores owing separate',
#  'targeting exploration programme',
#  'consideration following report presented separate volume',
#  'describing individual exploration programme operated',
#  'combined report table content',
#  'resource',
#  'volume resource',
#  'snaefell prospect geology structure',
#  'summary rehabilitation activity',
#  'summary',
#  'word',
#  'list figure',
#  'list table',
#  'appendix',
#  'introduction',
#  'tenure',
#  'regional geology',
#  'previous exploration',
#  'current exploration',
#  'snaefell prospect',
#  'exploration drilling',
#  'qaqc',
#  'accreditation',
#  'analysis quality control',
#  'regiona geology',
#  'snaefell conclusion',
#  'tomahawk prospect',
#  'hole location',
#  'geological logging',
#  'sampling methodology',
#  'tomahawk summary',
#  'environment',
#  'expenditure',
#  'bibliography',
#  'appendix',
#  'volume mineral',
#  'introduction',
#  'location',
#  'work area clearance',
#  'geophysics',
#  'ground gravity data collection',
#  'induced polarisation data collection',
#  'potential field data processing',
#  'data processing',
#  'regional exploration drilling',
#  'rouse',
#  'arapiles',
#  'shadwell',
#  'bumblebee',
#  'aquila',
#  'eccles',
#  'pocket knife',
#  'black hill south',
#  'copper knob',
#  'fyans',
#  'environment',
#  'work',
#  'reference',
#  'resource',
#  'mount wood project',
#  'combined annual report',
#  'period',
#  'january january',
#  'volume exploration',
#  'annual report period january january',
#  'resource',
#  'summary',
#  'report describes exploration activity undertaken resource mount',
#  'wood project licence january january',
#  'project located near coober pedy subject wood project amalgamated',
#  'expenditure agreement lodged',
#  'april joint venture entered mineral',
#  'exploration licence wood result certain',
#  'interest became duration exception iron',
#  'operator manager exploration retains right exploitable iron',
#  'field activity reporting period included diamond drilling snaefell',
#  'magnetite iron prospect drilling tomahawk magnetite iron prospect drill',
#  'hole summarised',
#  'tenement',
#  'total expenditure reporting period',
#  'data file listed verification table appendix',
#  'word',
#  'coober billa kalina mount wood',
#  'cairn iron oxide diamond',
#  'airborne gravity aeromagnetic geophysics',
#  'resource',
#  'annual report period january january',
#  'activity',
#  'hole',
#  'diamond drilling',
#  'rehabilitation',
#  'hole',
#  'hole',
#  'sample',
#  'metre',
#  'table content',
#  'summary',
#  'word',
#  'list figure',
#  'list table',
#  'appendix',
#  'introduction',
#  'tenure',
#  'regional geology',
#  'previous exploration',
#  'current exploration',
#  'snaefell prospect',
#  'exploration drilling',
#  'qaqc',
#  'accreditation',
#  'analysis quality control',
#  'regional geology',
#  'snaefell prospect geology structure',
#  'snaefell conclusion',
#  'tomahawk prospect',
#  'hole location',
#  'geological logging',
#  'sampling methodology',
#  'tomahawk summary',
#  'environment',
#  'summary rehabilitation activity',
#  'expenditure',
#  'bibliography',
#  'appendix',
#  'resource',
#  'annual report period january january',
#  'list figure',
#  'figure',
#  'location wood project licence',
#  'figure',
#  'exploration summary',
#  'figure',
#  'location snaefell prospect',
#  'figure',
#  'plan view interpreted fault drill hole vertical',
#  'derivative magnetite image core area snaefell',
#  'figure',
#  'cross section showing structural information',
#  'figure',
#  'location drill hole tomahawk target magnetics',
#  'figure',
#  'section tomahawk target drill hole',
#  'figure',
#  'snaefell july rehabilitation',
#  'figure',
#  'snaefell july rehabilitation',
#  'figure',
#  'snaefell collar rehabilitation',
#  'figure',
#  'snaefell collar rehabilitation',
#  'figure',
#  'hole capped tomahawk preventing wildlife entering drill hole',
#  'list table',
#  'table',
#  'tenure detail',
#  'table',
#  'exploration statistic',
#  'table',
#  'exploration statistic',
#  'table',
#  'exploration contractor consultant',
#  'table',
#  'summary element analysed',
#  'table',
#  'summary element analysed',
#  'table',
#  'significant interval tomahawk drilling',
#  'table',
#  'snaefell location rehabilitated site',
#  'table',
#  'expenditure january january',
#  'table',
#  'expenditure january january',
#  'resource',
#  'annual report period january january',
#  'appendix',
#  'resource estimation report',
#  'drilling data',
#  'metallurgy report',
#  'core photo government mineral resource drillhole',
#  'verification table',
#  'resource',
#  'annual report period january january',
#  'introduction',
#  'report detail exploration work undertaken exploration',
#  'includes',
#  'reporting',
#  'period january january location licence shown',
#  'figure',
#  'exploration licence located approximately coober',
#  'pedy cover area square resource hold',
#  'operation licence involve exploration',
#  'tenement start date expire',
#  'contains current high priority prospect',
#  'located approximately coober pedy cover area',
#  'square resource hold operation licence',
#  'involve exploration wood tenement start date',
#  'expire contains current high',
#  'priority target',
#  'north located approximately coober pedy cover',
#  'area square resource hold operation',
#  'licence involve exploration tenement start date',
#  'expire work completed',
#  'tenement resource current reporting',
#  'located approximately east coober pedy cover area',
#  'square resource hold operation licence',
#  'involve exploration licence start date',
#  'expire work completed tenement',
#  'resource current reporting',
#  'located approximately coober pedy cover area',
#  'square resource hold operation license',
#  'involve exploration licence start date',
#  'expire work completed',
#  'tenement resource current reporting',
#  'located approximately coober pedy cover area',
#  'square resource hold licence operation licence',
#  'involve exploration license start date',
#  'expired subsequent replacement licence application',
#  'submitted early outcome',
#  'exploration licence located northern gawler craton south access',
#  'sealed stuart highway series dirt station many become',
#  'impassable exploration licence situated mount penrhyn pastoral',
#  'resource',
#  'annual report period january january',
#  'lease within coober pedy sheet located within',
#  'woomera prohibited',
#  'main target area east stuart range edge',
#  'extensive undulating plain numerous gilgais',
#  'locally gibber cover',
#  'lower priority target western side stuart',
#  'formed eroding basement bulldog eroded shale silcrete resulted',
#  'mixture grey shale variegated hard soft soil consist',
#  'moderately deep crusty duplex soil minor silcrete',
#  'stuart range drainage divide separate creek feed lake eyre',
#  'basin creek drain towards great australian',
#  'siding',
#  'bulgaravhill',
#  'creek',
#  'woomera',
#  'prohibited',
#  'area',
#  'hill',
#  'carguaranorkacaano',
#  'kcooberpedy',
#  'hill',
#  'rise',
#  'rise',
#  'mount wood',
#  'hill',
#  'acodna',
#  'purvis',
#  'aprom',
#  'aingomar',
#  'mount sandy',
#  'figure location wood project licence',
#  'resource',
#  'annual report period january january',
#  'snaefell',
#  'drilling',
#  'figure exploration summary showing location high priority',
#  'annual report period january january',
#  'snaefell',
#  'resource',
#  'coober pedy',
#  'diamond',
#  'exploration summary',
#  'tomahawk',
#  'rcdrilling',
#  'figure',
#  'tenement',
#  'road',
#  'town',
#  'ktlometres',
#  'legend',
#  'tenurf',
#  'april joint venture entered',
#  'wood project retains right exploitable iron operator',
#  'manager exploration mineral except',
#  'table summarises tenure status mount wood exploration although cairn',
#  'hill mining lease resource owned located within',
#  'part group reporting therefore described',
#  'table tenure detail',
#  'licence',
#  'kangaroo',
#  'wood',
#  'warrina north',
#  'warrina south',
#  'brady',
#  'yarrabolina hill',
#  'resource',
#  'annual report period january january',
#  'granted',
#  'expiry',
#  'january',
#  'march',
#  'march',
#  'march',
#  'april',
#  'april',
#  'april',
#  'april',
#  'july',
#  'july',
#  'march',
#  'march',
#  'year',
#  'area',
#  'status',
#  'current',
#  'current',
#  'current',
#  'current',
#  'current',
#  'current',
#  'regional gfology',
#  'exploration licence cover part palaeoproterozoic mount wood tectonic block',
#  'variable magnetic intensity lying east southeast coober pedy ridge',
#  'mabe creek three terranes abut interpreted archaean cratonic area south',
#  'area contains major regional structure karari fault',
#  'traversed several prominent northwest trending',
#  'mount wood inlier comprises high grade granulite palaeoproterozoic',
#  'silicate rock forsterite metamorphic complex intruded',
#  'tectonic granitoids balta polyphase granite comprising',
#  'porphyritic granite hybrid metamorphics characterised',
#  'intense magnetic response regional aeromagnetic reflects combination',
#  'precursor including magnetite interpreted mafic',
#  'intrusive',
#  'mount wood inlier poorly limited outcrop gneiss',
#  'granite southeast gawler range volcanics archaean gneiss',
#  'south southwest wood basement outcrop within extremely',
#  'restricted small granite gneiss outcrop sparsely noted throughout',
#  'proterozoic basement overlain mesozoic tertiary sedimentary north',
#  'permian tallaringa cover thickness increase cover',
#  'thickness also increase presence permian cambrian sedimentary',
#  'increased thickness mesozoic cover sequence comprise cretaceous sediment',
#  'algebuckina sandstone bulldog turn',
#  'overlain ouaternary recent cover unit thicken south tenement',
#  'phillipson',
#  'within area basement blanketed variable thickness tertiary',
#  'holocene significant thickness permian kangaroo',
#  'wood area underlain dark grey shale friable sandstone',
#  'unit cretaceous bulldog',
#  'deep weathering produced profile pallid zone ferruginous mottled siliceous',
#  'layer layer opaline silica recognised extensive working opal',
#  'occur rise',
#  'resource',
#  'annual report period january january',
#  'previous fxploration',
#  'exploration iron coober pedy region undertaken delhi petroleum',
#  'extensive base precious metal minor uranium',
#  'diamond carried newmont exploration',
#  'mineral resource joint venture',
#  'basement outcrop within tenement previous exploration',
#  'strongly reliant geophysical drilling rotary',
#  'geophysical basement target cover extensive regiona drilling also',
#  'completed pirsa part south australian steel energy project phillipson',
#  'coober pedy sheet',
#  'crae explored area series search stratiform base',
#  'iocg program first systematic detailed exploration',
#  'bulk work current area carried',
#  'crae initially flew aeromagnetic radiometric survey little',
#  'work undertaken ground',
#  'selected number target coober pedy ridge project',
#  'magnetic survey confirmed anomaly twenty ranked three',
#  'target none within area current',
#  'managed joint venture carried geochemical orientation',
#  'regional aeromagnetic gravity detailed exploration selected',
#  'magnetic gravity target consisted detailed gravity snaefell',
#  'aquila target east mineralisation located',
#  'relinquished',
#  'goldstream mining acquired ground part',
#  'joint anglo managed initially iron oxide',
#  'work included ground magnetics gravity soil drilling',
#  'petrography anomalous mineralisation',
#  'noted basal portion associated pyrrhotite veinlets',
#  'locality subsequently called',
#  'management licence returned single drillhole',
#  'kangaroo prospect intersected within interval assaying',
#  'intersection associated geophysical feature extending',
#  'approximately twenty kilometre length interpreted body',
#  'resource',
#  'annual report period january january',
#  'exploration included ground magnetic surveying drilling',
#  'sample anglo hole analysed weakly',
#  'anomalous value previous data snaefell aquila',
#  'target acquired digital form pirsa reprocessed zonge engineering',
#  'exploration consisted diamond drilling analysis including petrology',
#  'water part pace collaborative drilling project five diamond drill hole',
#  'completed kangaroo result hole',
#  'exception intersected',
#  'including',
#  'also hole tested ground magnetic feature',
#  'snaefell hole tested anomaly tested uranium',
#  'returned intersection averaging returned',
#  'intersection hole ended magnetite mineralisation',
#  'anomaly intersected',
#  'abandoned failed reach target intersected slightly',
#  'elevated gold groundwater sample returned anomalous uranium',
#  'failed penetrate formation abandoned',
#  'scintillometer reading',
#  'exploration included line magnetics survey',
#  'mean height line spaced four rotary three water bore',
#  'rehabilitation anomalous uranium signature indicative proximal uranium',
#  'mineralisation drilling confirmed presence',
#  'significant thickness potential sedimentary host three bore',
#  'drilled adjacent four rotary uranium exploration hole part regional groundwater',
#  'monitoring program associated cairn hill mine groundwater supply',
#  'early changed name resource exploration',
#  'directed largely developing cairn hill magnetite deposit adjoining',
#  'granted cairn',
#  'kangaroo drilled anomaly',
#  'intersected amphibolite rock beneath cover',
#  'saprolitic neither intersected anomalous base metal',
#  'table summarises work completed',
#  'resource',
#  'annual report period january january',
#  'table exploration statistic',
#  'activity',
#  'hole',
#  'hole',
#  'survey',
#  'ground gravity survey',
#  'rehabilitation',
#  'survey line across aquila target obtained',
#  'chargeability anomaly ground gravity survey undertaken snaefell',
#  'prospect fitzgerald identifying coincident',
#  'anomaly',
#  'regional magnetic recently acquired',
#  'gravity data modelled drill hole',
#  'twelve hole completed others',
#  'fitzgerald',
#  'host sequence tightly folded',
#  'gneiss represent highly metamorphosed iron formation',
#  'carbonate mineralisation',
#  'sequence appears truncated fault parallel trend drilling',
#  'tested centre coincident magnetic gravity part eastern',
#  'successfully located wide zone',
#  'aquila complex target gravity anomaly near intersection',
#  'major regional structure possible conduit',
#  'three hole possible diamond tail designed target upper',
#  'part chargeability hole steepened missed',
#  'main part target chargeability',
#  'magnetic feature occurs western magnetic ridge extending westward',
#  'kangaroo modelling interpretation suggested converging magnetic',
#  'possibility mineralised dilation zone three hole tested feature',
#  'without',
#  'hole partially strongly magnetic hole intersected',
#  'gneiss second intersected interval',
#  'fitzgerald magnetic target lie magnetic linear towards western',
#  'side kangaroo hole intersected gneiss green',
#  'first hole intersected thick interval magnetite',
#  'including interval averaged',
#  'resource',
#  'annual report period january january',
#  'metre',
#  'station',
#  'sample',
#  'line',
#  'table summarises work completed',
#  'table exploration statistic',
#  'activity',
#  'diamond drilling',
#  'hole',
#  'petrology',
#  'metallurgy',
#  'rehabilitation',
#  'resource',
#  'annual report period january january',
#  'hole',
#  'tail',
#  'metre',
#  'station',
#  'line',
#  'sample',
#  'current exploration',
#  'exploration iron current reporting period focused',
#  'table list work undertaken contractor',
#  'table exploration contractor consultant',
#  'activity',
#  'diamond drilling',
#  'coughlan drilling',
#  'drilling',
#  'gorey cole drilling',
#  'rehabilitation',
#  'andy brockhoff',
#  'assaying',
#  'laboratory',
#  'metallurgy',
#  'magnetics gravity modelling',
#  'geological consultant',
#  'snaefell prospect',
#  'snaefell prospect located southeast coober east stuart',
#  'highway snaefell iron prospect comprising specular hematite',
#  'earthy prospect important potential contain greater',
#  'initial inferred resource estimate drilling carried july',
#  'current resource model expected upgrade resource estimation report',
#  'presented appendix',
#  'resource',
#  'annual report period january january',
#  'contractorlconsultant',
#  'figure location snaefell',
#  'exploration drilling',
#  'total drill hole completed snaefell prospect including diamond',
#  'hole drilling including collar downhole geology',
#  'survey geological code list presented appendix core photo presented',
#  'appendix government mineral resource drillhole database',
#  'april four hole drilled gain confidence resource',
#  'hole drilled south stopped nominal downhole depth',
#  'give vertica depth drill line spacing generally collar',
#  'spaced along drilling confirmed magnetite',
#  'mineralisation average grade iron continuous throughout',
#  'core area continues eastern part metallurgical',
#  'diamond hole targeting different mineralisation style also drilled',
#  'april metallurgical result positive viewed data report',
#  'appendix',
#  'hole totalling drilled gorey cole',
#  'drillers using truck mounted schram reverse circulation drill trailer',
#  'mounted hole spacing line spacing hole',
#  'designed test continuation magnetite increase inferred resource east west',
#  'drilling confirmed continuation magnetite along strike east west also',
#  'continuation northeast snaefell named',
#  'sequence thick occur core',
#  'weathering depth increased deposit around hole',
#  'resource',
#  'annual report period january january',
#  'dober pedy',
#  'snaefell',
#  'attn',
#  'hole location',
#  'hole collar location accurately surveyed surveyor trent cowan',
#  'resource cairn hill mine site resource exploration',
#  'geologist trimble differential used accuracy',
#  'relation base',
#  'downhole surveying',
#  'hole surveyed abim solution kalgoorlie using icefield downhole gyro',
#  'icefield gyro preferred instrument open hole',
#  'accommodate rougher memory gyro rather',
#  'calibrated monthly abims hole either kalgoorlie',
#  'abims operator dummy probe hole find depth',
#  'gyro instrument lowered depth',
#  'directional data acquired instrument pulled tool stopped every',
#  'azimuth azimuth collar hole entered zero',
#  'hole data collar location hole',
#  'obtained abims hole used reflex',
#  'instrument taken drilling azimuth estimated using either gyro data taken',
#  'unblocked portion last azimuth hole become blocked',
#  'copied bottom',
#  'hole surveyed abim solution kalgoorlie using north seeking gyro',
#  'generally open instrument refitted internal rubber buffer open',
#  'hole condition knock azimuth tolerance',
#  'gyro procedure first lower dummy probe check north seaking gyro',
#  'lowered bottom hole reading taken gyro pulled gyro',
#  'hung rough ground open causing incorrect gyro stopped every',
#  'azimuth gyro calibration checked periodically',
#  'abims test hole',
#  'hole used reflex instrument taken drilling',
#  'azimuth estimated using either gyro data taken unblocked portion',
#  'last azimuth hole became blocked copied bottom',
#  'previously individual metre sample collected entire',
#  'hole numbered green plastic sample split using',
#  'cyclone cone splitter calico bag composite sample taken',
#  'presplit bag snaefell bulk tonnage',
#  'complete hole metre basement intercept',
#  'geologist estimated composite sample',
#  'collected presplit calico unmineralised',
#  'sample collected split using spear',
#  'necessary previous experience weight magnetite sample resulted oversize',
#  'resulted triple processing splitting',
#  'blank standard routinely inserted sampling sequence every',
#  'discretion duplicate collected single split sample',
#  'thoroughly mixed split identical duplicate',
#  'occurred composite duplicate spear sample collected normal composite',
#  'sampling',
#  'september july cleaned quartz rich sand sourced coober',
#  'resource',
#  'annual report period january january',
#  'standard',
#  'blank',
#  'used',
#  'snaefell',
#  'pedy council le blank laboratory certified',
#  'value',
#  'sample initially pulverised micron genalysis adelaide',
#  'sent perth analysed standard iron suite element',
#  'reported element element analysed detection',
#  'detection limit',
#  'diameter diamond drill hole primarily drilled',
#  'metallurgy hole conventionally drilled cover sediment basement',
#  'intercept logged core logged detail sampling interval',
#  'mineralisation abundance core lengthwise sampling',
#  'usually longest sample quarter core used majority',
#  'core needed metalugical sample pulverised micron',
#  'genalysis element reported element element analysed',
#  'detection',
#  'nazo',
#  'detection limit',
#  'august november',
#  'drill cutting split onsite drilling using cyclone cone entire',
#  'hole individual sample collected numbered green plastic',
#  'split collected calico bag cone splitter representing',
#  'metre composite sample taken presplit snaefell',
#  'bulk tonnage complete hole metre basement intercept',
#  'geologist estimated composite',
#  'sample collected presplit calico unmineralised',
#  'sample collected split using spear',
#  'necessary previous experience weight magnetite sample resulted oversize',
#  'resulted triple processing splitting',
#  'blank standard routinely inserted sampling sequence every',
#  'discretion duplicate collected single split sample',
#  'thoroughly mixed split identical duplicate',
#  'occurred composite duplicate spear sample collected normal composite',
#  'sampling blank standard used snaefell',
#  'september november cleaned quartz rich sand sourced',
#  'coober pedy council le blank laboratory',
#  'certified value iron',
#  'sample initially pulverised micron genalysis adealide',
#  'sent perth analysed analysed detection',
#  'nazo',
#  'detection limit',
#  'august november',
#  'drill cutting split onsite drilling using cyclone riffle entire',
#  'hole individual sample collected numbered green plastic',
#  'split collected calico bag cone splitter representing drillers',
#  'cone splitter sample cone splitter could sent without need',
#  'resource',
#  'annual report period january january',
#  'spear reduce sample composite sample taken',
#  'presplit bag using',
#  'snaefell bulk tonnage complete hole metre',
#  'basement intercept geologist estimated',
#  'whole composite collected presplit calico',
#  'unmineralised sample collected',
#  'blank standard routinely inserted sampling sequence',
#  'every discretion duplicate collected single split',
#  'sample thoroughly mixed split identical',
#  'duplicate occurred composite duplicate spear sample collected',
#  'normal composite sampling',
#  'blank standard used snaefell september',
#  'november cleaned quartz rich sand sourced coober pedy council',
#  'le blank laboratory certified',
#  'value iron',
#  'sample initially pulverised micron genalysis adealide',
#  'sent perth analysed standard iron suite element',
#  'reported element element analysed detection shown',
#  'table',
#  'table summary element analysed',
#  'element',
#  'unit',
#  'detection',
#  'method',
#  'icalc',
#  'icalc',
#  'icalc',
#  'element',
#  'total',
#  'unit',
#  'detection',
#  'method',
#  'icalc',
#  'icalc',
#  'icalc',
#  'icalc',
#  'geological logging',
#  'logging',
#  'geologist grain lithology descriptive mineral',
#  'percentage sulphide mineral percentage',
#  'magsus data unit collected collar data including hole',
#  'core basement intercept base complete oxidation fresh rock',
#  'water drill driller data logged paper',
#  'entered checked submitted data exported micromine',
#  'rock chip collected chip tray stored exploration shed coober',
#  'pedy reference',
#  'resource',
#  'annual report period january january',
#  'diamond core logging',
#  'core collected field staff geologist brought exploration',
#  'oriented core mark bottom field staff assistance geologist',
#  'piece core together using purpose built angle iron three orientation line line solid',
#  'line marked along length core orientation mark otherwise',
#  'orientation mark line dotted line drawn natural break drill induced break',
#  'core cannot matched core metre marked using tape',
#  'measure cross referenced driller measurement mark core block inserted',
#  'drill core loss natural break fault',
#  'recorded geologist grain lithology descriptive',
#  'mineral percentage sulphide mineral percentage',
#  'magsus data unit collected meter',
#  'fugro geology interval logged geology mineralisation core',
#  'structurally logged using wrap around recording alpha beta alpha',
#  'beta angle converted using micromine excel data entry collar data',
#  'including hole core basement intercept base complete oxidation',
#  'fresh rock water drill driller data',
#  'logged paper entered checked submitted data',
#  'exported micromine diamond drill core stored exploration',
#  'qaqc',
#  'check included submitting duplicate custom crms',
#  'every batch genalysis full batch laboratory',
#  'performed check according',
#  'accreditation',
#  'accreditation ensures international standard maintained',
#  'reporting record national',
#  'association testing authority australia accredited genalysis laboratory service',
#  'following demonstration technical operate accordance',
#  'includes management requirement facility',
#  'accredited field chemical testing calibration measurement shown',
#  'scope accreditation issued nata',
#  'analysis quality control',
#  'certified reference material house split replicates analysed',
#  'batch quality control result reported along sample',
#  'value final',
#  'quality programme includes reference material ideally grade',
#  'matrix matched diverse number reference material used',
#  'regiona geology',
#  'mount wood inlier comprises high grade palaeoproterozoic metasedimentary rock',
#  'granulite facies',
#  'forsterite intruded',
#  'crms certified reference batch standard prepared three bulk',
#  'sample cairn hill crms prepared gannet holding',
#  'perth certified geostats',
#  'htplwwigenalysiscomaulanayicallgerneralinomationqualiycortrol',
#  'resource',
#  'annual report period january january',
#  'post tectonic granitoids balta polyphase hiltaba granite equivalent comprising',
#  'porphyritic granite hybrid covered mesozoic',
#  'tertiary sedimentary metasediments characterised intense magnetic',
#  'response regional aeromagnetic reflects combination magnetite rich precursor',
#  'sediment including magnetite alteration probable mafic intrusive inlier',
#  'bounded major shear prominent karari fault zone',
#  'bound trending coober pedy',
#  'snaefell prospect geology structure',
#  'snaefell prospect major magnetic linear feature interpreted magnetite',
#  'rich sedimentary gneiss locally rock tightly folded major fault',
#  'parallel trend snaefell gneiss unit prospect covered',
#  'tertiary holocene cover sediment comprising clay',
#  'unconsolidated immediately unconformity thick layer highly',
#  'weathered ferruginous felsic',
#  'highly weathered saprock land surface rock comprises',
#  'variably weathered altered smecite',
#  'depth magnetite generally undergone degree weathering',
#  'evidenced diamond hole within smectite zone',
#  'little earthy hematite specular hematite possible',
#  'also occurs magnetite notably north side snaefell many hole show',
#  'iron grade greater within variability',
#  'layered sedimentary origin magnetite becomes dominate iron',
#  'figure plan view interpreted fault drill hole vertical derivative',
#  'magnetic image core area snaefell',
#  'within gneiss significant marble unit identified traced',
#  'section upper marble unit probably facilitated slip',
#  'seems caught fault north side',
#  'chloritic shear separate underlying magnetite gneiss unit',
#  'resource',
#  'annual report period january january',
#  'package largely unmineralised felsic gneiss',
#  'structural information show foliation banding appear preferred',
#  'orientation steeply small scale',
#  'asymmetrical fold limb angle form overturned antiforms',
#  'steep southern limb northern immediately',
#  'gniessic banding dip steepens',
#  'approximately drilled south side',
#  'snaefell magnetic anomaly core orientation line',
#  'steep north structura data core area snaefell',
#  'show banding dip north near hanging wall shear',
#  'steepens approximate',
#  'figure cross section showing structural information',
#  'foliation banding coloured banding steepens towards',
#  'snaefell conclusion',
#  'diamond drill hole drilled tested centre',
#  'part snaefell host rock comprise tightly',
#  'folded sequence formation magnetite gneiss',
#  'subordinate perhaps thickened sequence',
#  'resource',
#  'annual report period january january',
#  'truncated fault approximately parallel strike orientation',
#  'sequence appears parallel main foliation host',
#  'dipping steeply north side sequence',
#  'appears truncated fault shear parallel trend',
#  'petrology diamond dril sample indicates formation metamorphic',
#  'metamorphic event greenschist',
#  'metamorphic event upper',
#  'metamorphic event',
#  'metamorphic sediment initial altered greenschist',
#  'facies metamorphism gneiss schist magnetite',
#  'plagioclase presence scapolite hint precursor evaporite',
#  'metamorphic event possibly occurred metasomatic event metamorphism oxidation',
#  'biotite became magnetite',
#  'thereby effectively upgrading primary presence',
#  'sample indicates metamorphism continued granulite facies late retrograde',
#  'metasomatic event potassic alteration formation',
#  'pervasive',
#  'metallurgy',
#  'initial davis tube recovery testing showed magnetite gneiss running could',
#  'upgraded logging diamond dril hole confirmed presence good',
#  'magnetite mineralisation also occurrence mixed iron',
#  'earthy hematite magnetite upper weathered zone',
#  'earthy hematite specular hematite',
#  'specular hematite',
#  'identification mixed iron addition',
#  'prompted detailed sighter beneficiation testwork metallurgy mixed variety',
#  'metallurgy result lims magnetic separation',
#  'micron could produce magnetite cairn snaefell',
#  'magnetite appears relatively potential lower capital',
#  'operating cost',
#  'tomahawk prospect',
#  'tomahawk iron prospect located southeast cairn hill',
#  'gold form part wood iron project south prospect',
#  'interpreted strike length vertical depth extent',
#  'tomahawk prospect strongest magnetic feature wood project area',
#  'target identified following detailed airborne geophysica survey completed',
#  'drilling program tested easternmost',
#  'corresponds intensely magnetic area drilling including collar',
#  'downhole geology survey geological code list presented',
#  'appendix',
#  'mineralisation intersected comprises layer magnetite within',
#  'part package includes gneiss',
#  'resource',
#  'annual report period january january',
#  'drilling program november gorey cole',
#  'drillers contracted carry program using schram reverse',
#  'circulation drill trailer mounted duration program',
#  'drill crew geologist field technician accommodated',
#  'mineral camp located skylark south east coober',
#  'locality',
#  'south australia',
#  'coober pedy',
#  'cairn mine',
#  'tomahawk',
#  'xolympcd',
#  'port',
#  'port',
#  'adelaide',
#  'tomahawk magnetite anomaly',
#  'figure location drill hole tomahawk target magnetics',
#  'hole location',
#  'hole surveyed reflex probe hole',
#  'surveyed using north seeking gyro',
#  'presence magnetite affecting',
#  'geological logging',
#  'cone splitter installed beneath attached side performed',
#  'split meter producing calico bag larger',
#  'presence unconsolidated hole collared plastic pipe depth',
#  'sample meter taken larger sieved washed',
#  'local coober pedy field technician logged geologist chip tray',
#  'interval used store representative portion sieved',
#  'geological cross section showing drill hole significant intersection',
#  'presented figure',
#  'resource',
#  'annual report period january january',
#  'figure section tomahawk target drill hole',
#  'sampling methodology',
#  'niton',
#  'starting analysed using thermo scientific niton',
#  'analysis performed manually compacted sample taken',
#  'centre larger case obviously sample several',
#  'performed result',
#  'magnetic susceptibility',
#  'starting magnetic susceptibility recorded using',
#  'magnetic susceptibility metre averaging',
#  'geochemical analysis',
#  'sample obtained sample',
#  'dispatched genalysis analysis analysis iron extended suite',
#  'fire assay completed',
#  'summary significant interval presented table',
#  'resource',
#  'annual report period january january',
#  'unconsolidated sediment',
#  'carbonate quartz',
#  'resource',
#  'tomahawk project',
#  'interpreter crose section',
#  'magnetite quartz',
#  'carbonate',
#  'azinuee',
#  'doto',
#  'drawn dforbes',
#  'table summary element analysed',
#  'element',
#  'unit',
#  'detection',
#  'method',
#  'icalc',
#  'ical',
#  'element',
#  'unit',
#  'detection',
#  'method',
#  'icalc',
#  'ical',
#  'table significant interval tomahawk drilling',
#  'hole',
#  'interval',
#  'including',
#  'including',
#  'including',
#  'including',
#  'including',
#  'tomahawk summary',
#  'conclusion initial drilling tomahawk series specific davis tube',
#  'recovery sample provided initial insight metallurgical',
#  'response result show magnetic fraction chemistry target sizing',
#  'appropriate initial',
#  'result tomahawk prospect hence exploration take place',
#  'order improve confidence metallurgica response along potential',
#  'size reporting completed neomet presented appendix',
#  'resource',
#  'annual report period january january',
#  'icalc',
#  'total',
#  'ical',
#  'ical',
#  'environment',
#  'accordance aboriginal heritage survey drill hole located',
#  'creek proximal drilling access drill site',
#  'station limiting damage native plastic calico bag currently',
#  'site collar covered plastic cap limit threat native',
#  'resource',
#  'annual report period january january',
#  'summary rfhabilitation activity',
#  'hole',
#  'backfilled abandoned according guideline given pirsa information sheet',
#  'plan submit series bulk sample snaefell prospect metallurgical testwork',
#  'sample bag remain representative image site showing rehab work',
#  'completed shown figure rehabilitation status drill hole',
#  'summarized table',
#  'figure snaefell july diamond hole plastic liner',
#  'sump',
#  'resource',
#  'annual report period january january',
#  'figure snaefell july hole hole',
#  'still',
#  'figure hole',
#  'resource',
#  'annual report period january january',
#  'figure hole rehabilitation',
#  'rehabilitation work described chai hodgson',
#  'preparation shallow sump deep',
#  'backhoe loader next hole contain potential saline ground water',
#  'encountered drilling well water pumped recirculated hole',
#  'course diamond drill hole sump lined',
#  'plastic',
#  'completion plastic liner removed disposed sump filled',
#  'area covered original',
#  'drill site rubbish sump necessary',
#  'surface scarified snaefell plan submit metallurgical testwork series bulk',
#  'sample green plastic bag containing drill currently remain',
#  'respective bag take time agreed periodically',
#  'green plastic',
#  'prospect lie within coober pedy precious mineral condition',
#  'requires sample hole collected submitted pirsa',
#  'coober material collected green',
#  'summary combined drilling rehabilitation activites',
#  'january combined wood report',
#  'resource',
#  'annual report period january january',
#  'table snaefell rehabilitated site',
#  'hole',
#  'hole',
#  'prospect',
#  'type',
#  'east',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  'snaefell',
#  ...]

# %%
new_lines=[] 
for line in lines: 
    splitline=line.split(' ') 
    new_lines.append(splitline)

# %%
new_lines
# Out:
# [['resource'],
#  ['combined', 'annual', 'report'],
#  ['mount', 'wood', 'project'],
#  ['period'],
#  ['february', 'january'],
#  ['resource'],
#  ['level', 'railway', 'road'],
#  ['subiaco'],
#  ['mineral'],
#  ['greenhill'],
#  ['parkside'],
#  ['lynch', 'damm', 'harris'],
#  ['tammi', 'doyle', 'yvette', 'laubsch'],
#  ['march'],
#  ['pirsa'],
#  ['resource'],
#  ['mineral'],
#  ['report',
#   'content',
#   'right',
#   'report',
#   'content',
#   'without',
#   'right',
#   'confidential'],
#  ['information',
#   'copy',
#   'right',
#   'work',
#   'map',
#   'comprised',
#   'remain',
#   'property'],
#  ['resource',
#   'part',
#   'report',
#   'information',
#   'contained',
#   'disclosed',
#   'person',
#   'without',
#   'consent'],
#  ['resource',
#   'part',
#   'report',
#   'information',
#   'contained',
#   'reproduced',
#   'stored'],
#  ['published', 'used', 'purpose', 'without', 'consent', 'resource'],
#  ['preface'],
#  ['wood', 'project', 'subject', 'joint', 'venture', 'agreement'],
#  ['resource', 'mineral', 'explores', 'iron'],
#  ['explores', 'owing', 'separate'],
#  ['targeting', 'exploration', 'programme'],
#  ['consideration', 'following', 'report', 'presented', 'separate', 'volume'],
#  ['describing', 'individual', 'exploration', 'programme', 'operated'],
#  ['combined', 'report', 'table', 'content'],
#  ['resource'],
#  ['volume', 'resource'],
#  ['snaefell', 'prospect', 'geology', 'structure'],
#  ['summary', 'rehabilitation', 'activity'],
#  ['summary'],
#  ['word'],
#  ['list', 'figure'],
#  ['list', 'table'],
#  ['appendix'],
#  ['introduction'],
#  ['tenure'],
#  ['regional', 'geology'],
#  ['previous', 'exploration'],
#  ['current', 'exploration'],
#  ['snaefell', 'prospect'],
#  ['exploration', 'drilling'],
#  ['qaqc'],
#  ['accreditation'],
#  ['analysis', 'quality', 'control'],
#  ['regiona', 'geology'],
#  ['snaefell', 'conclusion'],
#  ['tomahawk', 'prospect'],
#  ['hole', 'location'],
#  ['geological', 'logging'],
#  ['sampling', 'methodology'],
#  ['tomahawk', 'summary'],
#  ['environment'],
#  ['expenditure'],
#  ['bibliography'],
#  ['appendix'],
#  ['volume', 'mineral'],
#  ['introduction'],
#  ['location'],
#  ['work', 'area', 'clearance'],
#  ['geophysics'],
#  ['ground', 'gravity', 'data', 'collection'],
#  ['induced', 'polarisation', 'data', 'collection'],
#  ['potential', 'field', 'data', 'processing'],
#  ['data', 'processing'],
#  ['regional', 'exploration', 'drilling'],
#  ['rouse'],
#  ['arapiles'],
#  ['shadwell'],
#  ['bumblebee'],
#  ['aquila'],
#  ['eccles'],
#  ['pocket', 'knife'],
#  ['black', 'hill', 'south'],
#  ['copper', 'knob'],
#  ['fyans'],
#  ['environment'],
#  ['work'],
#  ['reference'],
#  ['resource'],
#  ['mount', 'wood', 'project'],
#  ['combined', 'annual', 'report'],
#  ['period'],
#  ['january', 'january'],
#  ['volume', 'exploration'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['resource'],
#  ['summary'],
#  ['report',
#   'describes',
#   'exploration',
#   'activity',
#   'undertaken',
#   'resource',
#   'mount'],
#  ['wood', 'project', 'licence', 'january', 'january'],
#  ['project',
#   'located',
#   'near',
#   'coober',
#   'pedy',
#   'subject',
#   'wood',
#   'project',
#   'amalgamated'],
#  ['expenditure', 'agreement', 'lodged'],
#  ['april', 'joint', 'venture', 'entered', 'mineral'],
#  ['exploration', 'licence', 'wood', 'result', 'certain'],
#  ['interest', 'became', 'duration', 'exception', 'iron'],
#  ['operator',
#   'manager',
#   'exploration',
#   'retains',
#   'right',
#   'exploitable',
#   'iron'],
#  ['field',
#   'activity',
#   'reporting',
#   'period',
#   'included',
#   'diamond',
#   'drilling',
#   'snaefell'],
#  ['magnetite',
#   'iron',
#   'prospect',
#   'drilling',
#   'tomahawk',
#   'magnetite',
#   'iron',
#   'prospect',
#   'drill'],
#  ['hole', 'summarised'],
#  ['tenement'],
#  ['total', 'expenditure', 'reporting', 'period'],
#  ['data', 'file', 'listed', 'verification', 'table', 'appendix'],
#  ['word'],
#  ['coober', 'billa', 'kalina', 'mount', 'wood'],
#  ['cairn', 'iron', 'oxide', 'diamond'],
#  ['airborne', 'gravity', 'aeromagnetic', 'geophysics'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['activity'],
#  ['hole'],
#  ['diamond', 'drilling'],
#  ['rehabilitation'],
#  ['hole'],
#  ['hole'],
#  ['sample'],
#  ['metre'],
#  ['table', 'content'],
#  ['summary'],
#  ['word'],
#  ['list', 'figure'],
#  ['list', 'table'],
#  ['appendix'],
#  ['introduction'],
#  ['tenure'],
#  ['regional', 'geology'],
#  ['previous', 'exploration'],
#  ['current', 'exploration'],
#  ['snaefell', 'prospect'],
#  ['exploration', 'drilling'],
#  ['qaqc'],
#  ['accreditation'],
#  ['analysis', 'quality', 'control'],
#  ['regional', 'geology'],
#  ['snaefell', 'prospect', 'geology', 'structure'],
#  ['snaefell', 'conclusion'],
#  ['tomahawk', 'prospect'],
#  ['hole', 'location'],
#  ['geological', 'logging'],
#  ['sampling', 'methodology'],
#  ['tomahawk', 'summary'],
#  ['environment'],
#  ['summary', 'rehabilitation', 'activity'],
#  ['expenditure'],
#  ['bibliography'],
#  ['appendix'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['list', 'figure'],
#  ['figure'],
#  ['location', 'wood', 'project', 'licence'],
#  ['figure'],
#  ['exploration', 'summary'],
#  ['figure'],
#  ['location', 'snaefell', 'prospect'],
#  ['figure'],
#  ['plan', 'view', 'interpreted', 'fault', 'drill', 'hole', 'vertical'],
#  ['derivative', 'magnetite', 'image', 'core', 'area', 'snaefell'],
#  ['figure'],
#  ['cross', 'section', 'showing', 'structural', 'information'],
#  ['figure'],
#  ['location', 'drill', 'hole', 'tomahawk', 'target', 'magnetics'],
#  ['figure'],
#  ['section', 'tomahawk', 'target', 'drill', 'hole'],
#  ['figure'],
#  ['snaefell', 'july', 'rehabilitation'],
#  ['figure'],
#  ['snaefell', 'july', 'rehabilitation'],
#  ['figure'],
#  ['snaefell', 'collar', 'rehabilitation'],
#  ['figure'],
#  ['snaefell', 'collar', 'rehabilitation'],
#  ['figure'],
#  ['hole',
#   'capped',
#   'tomahawk',
#   'preventing',
#   'wildlife',
#   'entering',
#   'drill',
#   'hole'],
#  ['list', 'table'],
#  ['table'],
#  ['tenure', 'detail'],
#  ['table'],
#  ['exploration', 'statistic'],
#  ['table'],
#  ['exploration', 'statistic'],
#  ['table'],
#  ['exploration', 'contractor', 'consultant'],
#  ['table'],
#  ['summary', 'element', 'analysed'],
#  ['table'],
#  ['summary', 'element', 'analysed'],
#  ['table'],
#  ['significant', 'interval', 'tomahawk', 'drilling'],
#  ['table'],
#  ['snaefell', 'location', 'rehabilitated', 'site'],
#  ['table'],
#  ['expenditure', 'january', 'january'],
#  ['table'],
#  ['expenditure', 'january', 'january'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['appendix'],
#  ['resource', 'estimation', 'report'],
#  ['drilling', 'data'],
#  ['metallurgy', 'report'],
#  ['core', 'photo', 'government', 'mineral', 'resource', 'drillhole'],
#  ['verification', 'table'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['introduction'],
#  ['report', 'detail', 'exploration', 'work', 'undertaken', 'exploration'],
#  ['includes'],
#  ['reporting'],
#  ['period', 'january', 'january', 'location', 'licence', 'shown'],
#  ['figure'],
#  ['exploration', 'licence', 'located', 'approximately', 'coober'],
#  ['pedy', 'cover', 'area', 'square', 'resource', 'hold'],
#  ['operation', 'licence', 'involve', 'exploration'],
#  ['tenement', 'start', 'date', 'expire'],
#  ['contains', 'current', 'high', 'priority', 'prospect'],
#  ['located', 'approximately', 'coober', 'pedy', 'cover', 'area'],
#  ['square', 'resource', 'hold', 'operation', 'licence'],
#  ['involve', 'exploration', 'wood', 'tenement', 'start', 'date'],
#  ['expire', 'contains', 'current', 'high'],
#  ['priority', 'target'],
#  ['north', 'located', 'approximately', 'coober', 'pedy', 'cover'],
#  ['area', 'square', 'resource', 'hold', 'operation'],
#  ['licence', 'involve', 'exploration', 'tenement', 'start', 'date'],
#  ['expire', 'work', 'completed'],
#  ['tenement', 'resource', 'current', 'reporting'],
#  ['located', 'approximately', 'east', 'coober', 'pedy', 'cover', 'area'],
#  ['square', 'resource', 'hold', 'operation', 'licence'],
#  ['involve', 'exploration', 'licence', 'start', 'date'],
#  ['expire', 'work', 'completed', 'tenement'],
#  ['resource', 'current', 'reporting'],
#  ['located', 'approximately', 'coober', 'pedy', 'cover', 'area'],
#  ['square', 'resource', 'hold', 'operation', 'license'],
#  ['involve', 'exploration', 'licence', 'start', 'date'],
#  ['expire', 'work', 'completed'],
#  ['tenement', 'resource', 'current', 'reporting'],
#  ['located', 'approximately', 'coober', 'pedy', 'cover', 'area'],
#  ['square', 'resource', 'hold', 'licence', 'operation', 'licence'],
#  ['involve', 'exploration', 'license', 'start', 'date'],
#  ['expired', 'subsequent', 'replacement', 'licence', 'application'],
#  ['submitted', 'early', 'outcome'],
#  ['exploration',
#   'licence',
#   'located',
#   'northern',
#   'gawler',
#   'craton',
#   'south',
#   'access'],
#  ['sealed',
#   'stuart',
#   'highway',
#   'series',
#   'dirt',
#   'station',
#   'many',
#   'become'],
#  ['impassable',
#   'exploration',
#   'licence',
#   'situated',
#   'mount',
#   'penrhyn',
#   'pastoral'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['lease', 'within', 'coober', 'pedy', 'sheet', 'located', 'within'],
#  ['woomera', 'prohibited'],
#  ['main', 'target', 'area', 'east', 'stuart', 'range', 'edge'],
#  ['extensive', 'undulating', 'plain', 'numerous', 'gilgais'],
#  ['locally', 'gibber', 'cover'],
#  ['lower', 'priority', 'target', 'western', 'side', 'stuart'],
#  ['formed',
#   'eroding',
#   'basement',
#   'bulldog',
#   'eroded',
#   'shale',
#   'silcrete',
#   'resulted'],
#  ['mixture', 'grey', 'shale', 'variegated', 'hard', 'soft', 'soil', 'consist'],
#  ['moderately', 'deep', 'crusty', 'duplex', 'soil', 'minor', 'silcrete'],
#  ['stuart',
#   'range',
#   'drainage',
#   'divide',
#   'separate',
#   'creek',
#   'feed',
#   'lake',
#   'eyre'],
#  ['basin', 'creek', 'drain', 'towards', 'great', 'australian'],
#  ['siding'],
#  ['bulgaravhill'],
#  ['creek'],
#  ['woomera'],
#  ['prohibited'],
#  ['area'],
#  ['hill'],
#  ['carguaranorkacaano'],
#  ['kcooberpedy'],
#  ['hill'],
#  ['rise'],
#  ['rise'],
#  ['mount', 'wood'],
#  ['hill'],
#  ['acodna'],
#  ['purvis'],
#  ['aprom'],
#  ['aingomar'],
#  ['mount', 'sandy'],
#  ['figure', 'location', 'wood', 'project', 'licence'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['snaefell'],
#  ['drilling'],
#  ['figure',
#   'exploration',
#   'summary',
#   'showing',
#   'location',
#   'high',
#   'priority'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['snaefell'],
#  ['resource'],
#  ['coober', 'pedy'],
#  ['diamond'],
#  ['exploration', 'summary'],
#  ['tomahawk'],
#  ['rcdrilling'],
#  ['figure'],
#  ['tenement'],
#  ['road'],
#  ['town'],
#  ['ktlometres'],
#  ['legend'],
#  ['tenurf'],
#  ['april', 'joint', 'venture', 'entered'],
#  ['wood', 'project', 'retains', 'right', 'exploitable', 'iron', 'operator'],
#  ['manager', 'exploration', 'mineral', 'except'],
#  ['table',
#   'summarises',
#   'tenure',
#   'status',
#   'mount',
#   'wood',
#   'exploration',
#   'although',
#   'cairn'],
#  ['hill', 'mining', 'lease', 'resource', 'owned', 'located', 'within'],
#  ['part', 'group', 'reporting', 'therefore', 'described'],
#  ['table', 'tenure', 'detail'],
#  ['licence'],
#  ['kangaroo'],
#  ['wood'],
#  ['warrina', 'north'],
#  ['warrina', 'south'],
#  ['brady'],
#  ['yarrabolina', 'hill'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['granted'],
#  ['expiry'],
#  ['january'],
#  ['march'],
#  ['march'],
#  ['march'],
#  ['april'],
#  ['april'],
#  ['april'],
#  ['april'],
#  ['july'],
#  ['july'],
#  ['march'],
#  ['march'],
#  ['year'],
#  ['area'],
#  ['status'],
#  ['current'],
#  ['current'],
#  ['current'],
#  ['current'],
#  ['current'],
#  ['current'],
#  ['regional', 'gfology'],
#  ['exploration',
#   'licence',
#   'cover',
#   'part',
#   'palaeoproterozoic',
#   'mount',
#   'wood',
#   'tectonic',
#   'block'],
#  ['variable',
#   'magnetic',
#   'intensity',
#   'lying',
#   'east',
#   'southeast',
#   'coober',
#   'pedy',
#   'ridge'],
#  ['mabe',
#   'creek',
#   'three',
#   'terranes',
#   'abut',
#   'interpreted',
#   'archaean',
#   'cratonic',
#   'area',
#   'south'],
#  ['area', 'contains', 'major', 'regional', 'structure', 'karari', 'fault'],
#  ['traversed', 'several', 'prominent', 'northwest', 'trending'],
#  ['mount',
#   'wood',
#   'inlier',
#   'comprises',
#   'high',
#   'grade',
#   'granulite',
#   'palaeoproterozoic'],
#  ['silicate', 'rock', 'forsterite', 'metamorphic', 'complex', 'intruded'],
#  ['tectonic', 'granitoids', 'balta', 'polyphase', 'granite', 'comprising'],
#  ['porphyritic', 'granite', 'hybrid', 'metamorphics', 'characterised'],
#  ['intense',
#   'magnetic',
#   'response',
#   'regional',
#   'aeromagnetic',
#   'reflects',
#   'combination'],
#  ['precursor', 'including', 'magnetite', 'interpreted', 'mafic'],
#  ['intrusive'],
#  ['mount', 'wood', 'inlier', 'poorly', 'limited', 'outcrop', 'gneiss'],
#  ['granite',
#   'southeast',
#   'gawler',
#   'range',
#   'volcanics',
#   'archaean',
#   'gneiss'],
#  ['south', 'southwest', 'wood', 'basement', 'outcrop', 'within', 'extremely'],
#  ['restricted',
#   'small',
#   'granite',
#   'gneiss',
#   'outcrop',
#   'sparsely',
#   'noted',
#   'throughout'],
#  ['proterozoic',
#   'basement',
#   'overlain',
#   'mesozoic',
#   'tertiary',
#   'sedimentary',
#   'north'],
#  ['permian', 'tallaringa', 'cover', 'thickness', 'increase', 'cover'],
#  ['thickness',
#   'also',
#   'increase',
#   'presence',
#   'permian',
#   'cambrian',
#   'sedimentary'],
#  ['increased',
#   'thickness',
#   'mesozoic',
#   'cover',
#   'sequence',
#   'comprise',
#   'cretaceous',
#   'sediment'],
#  ['algebuckina', 'sandstone', 'bulldog', 'turn'],
#  ['overlain',
#   'ouaternary',
#   'recent',
#   'cover',
#   'unit',
#   'thicken',
#   'south',
#   'tenement'],
#  ['phillipson'],
#  ['within',
#   'area',
#   'basement',
#   'blanketed',
#   'variable',
#   'thickness',
#   'tertiary'],
#  ['holocene', 'significant', 'thickness', 'permian', 'kangaroo'],
#  ['wood',
#   'area',
#   'underlain',
#   'dark',
#   'grey',
#   'shale',
#   'friable',
#   'sandstone'],
#  ['unit', 'cretaceous', 'bulldog'],
#  ['deep',
#   'weathering',
#   'produced',
#   'profile',
#   'pallid',
#   'zone',
#   'ferruginous',
#   'mottled',
#   'siliceous'],
#  ['layer',
#   'layer',
#   'opaline',
#   'silica',
#   'recognised',
#   'extensive',
#   'working',
#   'opal'],
#  ['occur', 'rise'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['previous', 'fxploration'],
#  ['exploration',
#   'iron',
#   'coober',
#   'pedy',
#   'region',
#   'undertaken',
#   'delhi',
#   'petroleum'],
#  ['extensive', 'base', 'precious', 'metal', 'minor', 'uranium'],
#  ['diamond', 'carried', 'newmont', 'exploration'],
#  ['mineral', 'resource', 'joint', 'venture'],
#  ['basement', 'outcrop', 'within', 'tenement', 'previous', 'exploration'],
#  ['strongly', 'reliant', 'geophysical', 'drilling', 'rotary'],
#  ['geophysical',
#   'basement',
#   'target',
#   'cover',
#   'extensive',
#   'regiona',
#   'drilling',
#   'also'],
#  ['completed',
#   'pirsa',
#   'part',
#   'south',
#   'australian',
#   'steel',
#   'energy',
#   'project',
#   'phillipson'],
#  ['coober', 'pedy', 'sheet'],
#  ['crae', 'explored', 'area', 'series', 'search', 'stratiform', 'base'],
#  ['iocg', 'program', 'first', 'systematic', 'detailed', 'exploration'],
#  ['bulk', 'work', 'current', 'area', 'carried'],
#  ['crae',
#   'initially',
#   'flew',
#   'aeromagnetic',
#   'radiometric',
#   'survey',
#   'little'],
#  ['work', 'undertaken', 'ground'],
#  ['selected', 'number', 'target', 'coober', 'pedy', 'ridge', 'project'],
#  ['magnetic', 'survey', 'confirmed', 'anomaly', 'twenty', 'ranked', 'three'],
#  ['target', 'none', 'within', 'area', 'current'],
#  ['managed', 'joint', 'venture', 'carried', 'geochemical', 'orientation'],
#  ['regional',
#   'aeromagnetic',
#   'gravity',
#   'detailed',
#   'exploration',
#   'selected'],
#  ['magnetic',
#   'gravity',
#   'target',
#   'consisted',
#   'detailed',
#   'gravity',
#   'snaefell'],
#  ['aquila', 'target', 'east', 'mineralisation', 'located'],
#  ['relinquished'],
#  ['goldstream', 'mining', 'acquired', 'ground', 'part'],
#  ['joint', 'anglo', 'managed', 'initially', 'iron', 'oxide'],
#  ['work', 'included', 'ground', 'magnetics', 'gravity', 'soil', 'drilling'],
#  ['petrography', 'anomalous', 'mineralisation'],
#  ['noted', 'basal', 'portion', 'associated', 'pyrrhotite', 'veinlets'],
#  ['locality', 'subsequently', 'called'],
#  ['management', 'licence', 'returned', 'single', 'drillhole'],
#  ['kangaroo', 'prospect', 'intersected', 'within', 'interval', 'assaying'],
#  ['intersection', 'associated', 'geophysical', 'feature', 'extending'],
#  ['approximately', 'twenty', 'kilometre', 'length', 'interpreted', 'body'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['exploration', 'included', 'ground', 'magnetic', 'surveying', 'drilling'],
#  ['sample', 'anglo', 'hole', 'analysed', 'weakly'],
#  ['anomalous', 'value', 'previous', 'data', 'snaefell', 'aquila'],
#  ['target',
#   'acquired',
#   'digital',
#   'form',
#   'pirsa',
#   'reprocessed',
#   'zonge',
#   'engineering'],
#  ['exploration',
#   'consisted',
#   'diamond',
#   'drilling',
#   'analysis',
#   'including',
#   'petrology'],
#  ['water',
#   'part',
#   'pace',
#   'collaborative',
#   'drilling',
#   'project',
#   'five',
#   'diamond',
#   'drill',
#   'hole'],
#  ['completed', 'kangaroo', 'result', 'hole'],
#  ['exception', 'intersected'],
#  ['including'],
#  ['also', 'hole', 'tested', 'ground', 'magnetic', 'feature'],
#  ['snaefell', 'hole', 'tested', 'anomaly', 'tested', 'uranium'],
#  ['returned', 'intersection', 'averaging', 'returned'],
#  ['intersection', 'hole', 'ended', 'magnetite', 'mineralisation'],
#  ['anomaly', 'intersected'],
#  ['abandoned', 'failed', 'reach', 'target', 'intersected', 'slightly'],
#  ['elevated',
#   'gold',
#   'groundwater',
#   'sample',
#   'returned',
#   'anomalous',
#   'uranium'],
#  ['failed', 'penetrate', 'formation', 'abandoned'],
#  ['scintillometer', 'reading'],
#  ['exploration', 'included', 'line', 'magnetics', 'survey'],
#  ['mean',
#   'height',
#   'line',
#   'spaced',
#   'four',
#   'rotary',
#   'three',
#   'water',
#   'bore'],
#  ['rehabilitation',
#   'anomalous',
#   'uranium',
#   'signature',
#   'indicative',
#   'proximal',
#   'uranium'],
#  ['mineralisation', 'drilling', 'confirmed', 'presence'],
#  ['significant',
#   'thickness',
#   'potential',
#   'sedimentary',
#   'host',
#   'three',
#   'bore'],
#  ['drilled',
#   'adjacent',
#   'four',
#   'rotary',
#   'uranium',
#   'exploration',
#   'hole',
#   'part',
#   'regional',
#   'groundwater'],
#  ['monitoring',
#   'program',
#   'associated',
#   'cairn',
#   'hill',
#   'mine',
#   'groundwater',
#   'supply'],
#  ['early', 'changed', 'name', 'resource', 'exploration'],
#  ['directed',
#   'largely',
#   'developing',
#   'cairn',
#   'hill',
#   'magnetite',
#   'deposit',
#   'adjoining'],
#  ['granted', 'cairn'],
#  ['kangaroo', 'drilled', 'anomaly'],
#  ['intersected', 'amphibolite', 'rock', 'beneath', 'cover'],
#  ['saprolitic', 'neither', 'intersected', 'anomalous', 'base', 'metal'],
#  ['table', 'summarises', 'work', 'completed'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['table', 'exploration', 'statistic'],
#  ['activity'],
#  ['hole'],
#  ['hole'],
#  ['survey'],
#  ['ground', 'gravity', 'survey'],
#  ['rehabilitation'],
#  ['survey', 'line', 'across', 'aquila', 'target', 'obtained'],
#  ['chargeability',
#   'anomaly',
#   'ground',
#   'gravity',
#   'survey',
#   'undertaken',
#   'snaefell'],
#  ['prospect', 'fitzgerald', 'identifying', 'coincident'],
#  ['anomaly'],
#  ['regional', 'magnetic', 'recently', 'acquired'],
#  ['gravity', 'data', 'modelled', 'drill', 'hole'],
#  ['twelve', 'hole', 'completed', 'others'],
#  ['fitzgerald'],
#  ['host', 'sequence', 'tightly', 'folded'],
#  ['gneiss', 'represent', 'highly', 'metamorphosed', 'iron', 'formation'],
#  ['carbonate', 'mineralisation'],
#  ['sequence',
#   'appears',
#   'truncated',
#   'fault',
#   'parallel',
#   'trend',
#   'drilling'],
#  ['tested', 'centre', 'coincident', 'magnetic', 'gravity', 'part', 'eastern'],
#  ['successfully', 'located', 'wide', 'zone'],
#  ['aquila', 'complex', 'target', 'gravity', 'anomaly', 'near', 'intersection'],
#  ['major', 'regional', 'structure', 'possible', 'conduit'],
#  ['three',
#   'hole',
#   'possible',
#   'diamond',
#   'tail',
#   'designed',
#   'target',
#   'upper'],
#  ['part', 'chargeability', 'hole', 'steepened', 'missed'],
#  ['main', 'part', 'target', 'chargeability'],
#  ['magnetic',
#   'feature',
#   'occurs',
#   'western',
#   'magnetic',
#   'ridge',
#   'extending',
#   'westward'],
#  ['kangaroo',
#   'modelling',
#   'interpretation',
#   'suggested',
#   'converging',
#   'magnetic'],
#  ['possibility',
#   'mineralised',
#   'dilation',
#   'zone',
#   'three',
#   'hole',
#   'tested',
#   'feature'],
#  ['without'],
#  ['hole', 'partially', 'strongly', 'magnetic', 'hole', 'intersected'],
#  ['gneiss', 'second', 'intersected', 'interval'],
#  ['fitzgerald',
#   'magnetic',
#   'target',
#   'lie',
#   'magnetic',
#   'linear',
#   'towards',
#   'western'],
#  ['side', 'kangaroo', 'hole', 'intersected', 'gneiss', 'green'],
#  ['first', 'hole', 'intersected', 'thick', 'interval', 'magnetite'],
#  ['including', 'interval', 'averaged'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['metre'],
#  ['station'],
#  ['sample'],
#  ['line'],
#  ['table', 'summarises', 'work', 'completed'],
#  ['table', 'exploration', 'statistic'],
#  ['activity'],
#  ['diamond', 'drilling'],
#  ['hole'],
#  ['petrology'],
#  ['metallurgy'],
#  ['rehabilitation'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['hole'],
#  ['tail'],
#  ['metre'],
#  ['station'],
#  ['line'],
#  ['sample'],
#  ['current', 'exploration'],
#  ['exploration', 'iron', 'current', 'reporting', 'period', 'focused'],
#  ['table', 'list', 'work', 'undertaken', 'contractor'],
#  ['table', 'exploration', 'contractor', 'consultant'],
#  ['activity'],
#  ['diamond', 'drilling'],
#  ['coughlan', 'drilling'],
#  ['drilling'],
#  ['gorey', 'cole', 'drilling'],
#  ['rehabilitation'],
#  ['andy', 'brockhoff'],
#  ['assaying'],
#  ['laboratory'],
#  ['metallurgy'],
#  ['magnetics', 'gravity', 'modelling'],
#  ['geological', 'consultant'],
#  ['snaefell', 'prospect'],
#  ['snaefell', 'prospect', 'located', 'southeast', 'coober', 'east', 'stuart'],
#  ['highway',
#   'snaefell',
#   'iron',
#   'prospect',
#   'comprising',
#   'specular',
#   'hematite'],
#  ['earthy', 'prospect', 'important', 'potential', 'contain', 'greater'],
#  ['initial',
#   'inferred',
#   'resource',
#   'estimate',
#   'drilling',
#   'carried',
#   'july'],
#  ['current',
#   'resource',
#   'model',
#   'expected',
#   'upgrade',
#   'resource',
#   'estimation',
#   'report'],
#  ['presented', 'appendix'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['contractorlconsultant'],
#  ['figure', 'location', 'snaefell'],
#  ['exploration', 'drilling'],
#  ['total',
#   'drill',
#   'hole',
#   'completed',
#   'snaefell',
#   'prospect',
#   'including',
#   'diamond'],
#  ['hole', 'drilling', 'including', 'collar', 'downhole', 'geology'],
#  ['survey',
#   'geological',
#   'code',
#   'list',
#   'presented',
#   'appendix',
#   'core',
#   'photo',
#   'presented'],
#  ['appendix', 'government', 'mineral', 'resource', 'drillhole', 'database'],
#  ['april', 'four', 'hole', 'drilled', 'gain', 'confidence', 'resource'],
#  ['hole', 'drilled', 'south', 'stopped', 'nominal', 'downhole', 'depth'],
#  ['give',
#   'vertica',
#   'depth',
#   'drill',
#   'line',
#   'spacing',
#   'generally',
#   'collar'],
#  ['spaced', 'along', 'drilling', 'confirmed', 'magnetite'],
#  ['mineralisation', 'average', 'grade', 'iron', 'continuous', 'throughout'],
#  ['core', 'area', 'continues', 'eastern', 'part', 'metallurgical'],
#  ['diamond',
#   'hole',
#   'targeting',
#   'different',
#   'mineralisation',
#   'style',
#   'also',
#   'drilled'],
#  ['april', 'metallurgical', 'result', 'positive', 'viewed', 'data', 'report'],
#  ['appendix'],
#  ['hole', 'totalling', 'drilled', 'gorey', 'cole'],
#  ['drillers',
#   'using',
#   'truck',
#   'mounted',
#   'schram',
#   'reverse',
#   'circulation',
#   'drill',
#   'trailer'],
#  ['mounted', 'hole', 'spacing', 'line', 'spacing', 'hole'],
#  ['designed',
#   'test',
#   'continuation',
#   'magnetite',
#   'increase',
#   'inferred',
#   'resource',
#   'east',
#   'west'],
#  ['drilling',
#   'confirmed',
#   'continuation',
#   'magnetite',
#   'along',
#   'strike',
#   'east',
#   'west',
#   'also'],
#  ['continuation', 'northeast', 'snaefell', 'named'],
#  ['sequence', 'thick', 'occur', 'core'],
#  ['weathering', 'depth', 'increased', 'deposit', 'around', 'hole'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['dober', 'pedy'],
#  ['snaefell'],
#  ['attn'],
#  ['hole', 'location'],
#  ['hole',
#   'collar',
#   'location',
#   'accurately',
#   'surveyed',
#   'surveyor',
#   'trent',
#   'cowan'],
#  ['resource', 'cairn', 'hill', 'mine', 'site', 'resource', 'exploration'],
#  ['geologist', 'trimble', 'differential', 'used', 'accuracy'],
#  ['relation', 'base'],
#  ['downhole', 'surveying'],
#  ['hole',
#   'surveyed',
#   'abim',
#   'solution',
#   'kalgoorlie',
#   'using',
#   'icefield',
#   'downhole',
#   'gyro'],
#  ['icefield', 'gyro', 'preferred', 'instrument', 'open', 'hole'],
#  ['accommodate', 'rougher', 'memory', 'gyro', 'rather'],
#  ['calibrated', 'monthly', 'abims', 'hole', 'either', 'kalgoorlie'],
#  ['abims', 'operator', 'dummy', 'probe', 'hole', 'find', 'depth'],
#  ['gyro', 'instrument', 'lowered', 'depth'],
#  ['directional',
#   'data',
#   'acquired',
#   'instrument',
#   'pulled',
#   'tool',
#   'stopped',
#   'every'],
#  ['azimuth', 'azimuth', 'collar', 'hole', 'entered', 'zero'],
#  ['hole', 'data', 'collar', 'location', 'hole'],
#  ['obtained', 'abims', 'hole', 'used', 'reflex'],
#  ['instrument',
#   'taken',
#   'drilling',
#   'azimuth',
#   'estimated',
#   'using',
#   'either',
#   'gyro',
#   'data',
#   'taken'],
#  ['unblocked', 'portion', 'last', 'azimuth', 'hole', 'become', 'blocked'],
#  ['copied', 'bottom'],
#  ['hole',
#   'surveyed',
#   'abim',
#   'solution',
#   'kalgoorlie',
#   'using',
#   'north',
#   'seeking',
#   'gyro'],
#  ['generally',
#   'open',
#   'instrument',
#   'refitted',
#   'internal',
#   'rubber',
#   'buffer',
#   'open'],
#  ['hole', 'condition', 'knock', 'azimuth', 'tolerance'],
#  ['gyro',
#   'procedure',
#   'first',
#   'lower',
#   'dummy',
#   'probe',
#   'check',
#   'north',
#   'seaking',
#   'gyro'],
#  ['lowered', 'bottom', 'hole', 'reading', 'taken', 'gyro', 'pulled', 'gyro'],
#  ['hung',
#   'rough',
#   'ground',
#   'open',
#   'causing',
#   'incorrect',
#   'gyro',
#   'stopped',
#   'every'],
#  ['azimuth', 'gyro', 'calibration', 'checked', 'periodically'],
#  ['abims', 'test', 'hole'],
#  ['hole', 'used', 'reflex', 'instrument', 'taken', 'drilling'],
#  ['azimuth',
#   'estimated',
#   'using',
#   'either',
#   'gyro',
#   'data',
#   'taken',
#   'unblocked',
#   'portion'],
#  ['last', 'azimuth', 'hole', 'became', 'blocked', 'copied', 'bottom'],
#  ['previously', 'individual', 'metre', 'sample', 'collected', 'entire'],
#  ['hole', 'numbered', 'green', 'plastic', 'sample', 'split', 'using'],
#  ['cyclone',
#   'cone',
#   'splitter',
#   'calico',
#   'bag',
#   'composite',
#   'sample',
#   'taken'],
#  ['presplit', 'bag', 'snaefell', 'bulk', 'tonnage'],
#  ['complete', 'hole', 'metre', 'basement', 'intercept'],
#  ['geologist', 'estimated', 'composite', 'sample'],
#  ['collected', 'presplit', 'calico', 'unmineralised'],
#  ['sample', 'collected', 'split', 'using', 'spear'],
#  ['necessary',
#   'previous',
#   'experience',
#   'weight',
#   'magnetite',
#   'sample',
#   'resulted',
#   'oversize'],
#  ['resulted', 'triple', 'processing', 'splitting'],
#  ['blank',
#   'standard',
#   'routinely',
#   'inserted',
#   'sampling',
#   'sequence',
#   'every'],
#  ['discretion', 'duplicate', 'collected', 'single', 'split', 'sample'],
#  ['thoroughly', 'mixed', 'split', 'identical', 'duplicate'],
#  ['occurred',
#   'composite',
#   'duplicate',
#   'spear',
#   'sample',
#   'collected',
#   'normal',
#   'composite'],
#  ['sampling'],
#  ['september',
#   'july',
#   'cleaned',
#   'quartz',
#   'rich',
#   'sand',
#   'sourced',
#   'coober'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['standard'],
#  ['blank'],
#  ['used'],
#  ['snaefell'],
#  ['pedy', 'council', 'le', 'blank', 'laboratory', 'certified'],
#  ['value'],
#  ['sample', 'initially', 'pulverised', 'micron', 'genalysis', 'adelaide'],
#  ['sent', 'perth', 'analysed', 'standard', 'iron', 'suite', 'element'],
#  ['reported', 'element', 'element', 'analysed', 'detection'],
#  ['detection', 'limit'],
#  ['diameter', 'diamond', 'drill', 'hole', 'primarily', 'drilled'],
#  ['metallurgy',
#   'hole',
#   'conventionally',
#   'drilled',
#   'cover',
#   'sediment',
#   'basement'],
#  ['intercept', 'logged', 'core', 'logged', 'detail', 'sampling', 'interval'],
#  ['mineralisation', 'abundance', 'core', 'lengthwise', 'sampling'],
#  ['usually', 'longest', 'sample', 'quarter', 'core', 'used', 'majority'],
#  ['core', 'needed', 'metalugical', 'sample', 'pulverised', 'micron'],
#  ['genalysis', 'element', 'reported', 'element', 'element', 'analysed'],
#  ['detection'],
#  ['nazo'],
#  ['detection', 'limit'],
#  ['august', 'november'],
#  ['drill',
#   'cutting',
#   'split',
#   'onsite',
#   'drilling',
#   'using',
#   'cyclone',
#   'cone',
#   'entire'],
#  ['hole', 'individual', 'sample', 'collected', 'numbered', 'green', 'plastic'],
#  ['split', 'collected', 'calico', 'bag', 'cone', 'splitter', 'representing'],
#  ['metre', 'composite', 'sample', 'taken', 'presplit', 'snaefell'],
#  ['bulk', 'tonnage', 'complete', 'hole', 'metre', 'basement', 'intercept'],
#  ['geologist', 'estimated', 'composite'],
#  ['sample', 'collected', 'presplit', 'calico', 'unmineralised'],
#  ['sample', 'collected', 'split', 'using', 'spear'],
#  ['necessary',
#   'previous',
#   'experience',
#   'weight',
#   'magnetite',
#   'sample',
#   'resulted',
#   'oversize'],
#  ['resulted', 'triple', 'processing', 'splitting'],
#  ['blank',
#   'standard',
#   'routinely',
#   'inserted',
#   'sampling',
#   'sequence',
#   'every'],
#  ['discretion', 'duplicate', 'collected', 'single', 'split', 'sample'],
#  ['thoroughly', 'mixed', 'split', 'identical', 'duplicate'],
#  ['occurred',
#   'composite',
#   'duplicate',
#   'spear',
#   'sample',
#   'collected',
#   'normal',
#   'composite'],
#  ['sampling', 'blank', 'standard', 'used', 'snaefell'],
#  ['september', 'november', 'cleaned', 'quartz', 'rich', 'sand', 'sourced'],
#  ['coober', 'pedy', 'council', 'le', 'blank', 'laboratory'],
#  ['certified', 'value', 'iron'],
#  ['sample', 'initially', 'pulverised', 'micron', 'genalysis', 'adealide'],
#  ['sent', 'perth', 'analysed', 'analysed', 'detection'],
#  ['nazo'],
#  ['detection', 'limit'],
#  ['august', 'november'],
#  ['drill',
#   'cutting',
#   'split',
#   'onsite',
#   'drilling',
#   'using',
#   'cyclone',
#   'riffle',
#   'entire'],
#  ['hole', 'individual', 'sample', 'collected', 'numbered', 'green', 'plastic'],
#  ['split',
#   'collected',
#   'calico',
#   'bag',
#   'cone',
#   'splitter',
#   'representing',
#   'drillers'],
#  ['cone',
#   'splitter',
#   'sample',
#   'cone',
#   'splitter',
#   'could',
#   'sent',
#   'without',
#   'need'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['spear', 'reduce', 'sample', 'composite', 'sample', 'taken'],
#  ['presplit', 'bag', 'using'],
#  ['snaefell', 'bulk', 'tonnage', 'complete', 'hole', 'metre'],
#  ['basement', 'intercept', 'geologist', 'estimated'],
#  ['whole', 'composite', 'collected', 'presplit', 'calico'],
#  ['unmineralised', 'sample', 'collected'],
#  ['blank', 'standard', 'routinely', 'inserted', 'sampling', 'sequence'],
#  ['every', 'discretion', 'duplicate', 'collected', 'single', 'split'],
#  ['sample', 'thoroughly', 'mixed', 'split', 'identical'],
#  ['duplicate',
#   'occurred',
#   'composite',
#   'duplicate',
#   'spear',
#   'sample',
#   'collected'],
#  ['normal', 'composite', 'sampling'],
#  ['blank', 'standard', 'used', 'snaefell', 'september'],
#  ['november',
#   'cleaned',
#   'quartz',
#   'rich',
#   'sand',
#   'sourced',
#   'coober',
#   'pedy',
#   'council'],
#  ['le', 'blank', 'laboratory', 'certified'],
#  ['value', 'iron'],
#  ['sample', 'initially', 'pulverised', 'micron', 'genalysis', 'adealide'],
#  ['sent', 'perth', 'analysed', 'standard', 'iron', 'suite', 'element'],
#  ['reported', 'element', 'element', 'analysed', 'detection', 'shown'],
#  ['table'],
#  ['table', 'summary', 'element', 'analysed'],
#  ['element'],
#  ['unit'],
#  ['detection'],
#  ['method'],
#  ['icalc'],
#  ['icalc'],
#  ['icalc'],
#  ['element'],
#  ['total'],
#  ['unit'],
#  ['detection'],
#  ['method'],
#  ['icalc'],
#  ['icalc'],
#  ['icalc'],
#  ['icalc'],
#  ['geological', 'logging'],
#  ['logging'],
#  ['geologist', 'grain', 'lithology', 'descriptive', 'mineral'],
#  ['percentage', 'sulphide', 'mineral', 'percentage'],
#  ['magsus',
#   'data',
#   'unit',
#   'collected',
#   'collar',
#   'data',
#   'including',
#   'hole'],
#  ['core',
#   'basement',
#   'intercept',
#   'base',
#   'complete',
#   'oxidation',
#   'fresh',
#   'rock'],
#  ['water', 'drill', 'driller', 'data', 'logged', 'paper'],
#  ['entered', 'checked', 'submitted', 'data', 'exported', 'micromine'],
#  ['rock',
#   'chip',
#   'collected',
#   'chip',
#   'tray',
#   'stored',
#   'exploration',
#   'shed',
#   'coober'],
#  ['pedy', 'reference'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['diamond', 'core', 'logging'],
#  ['core',
#   'collected',
#   'field',
#   'staff',
#   'geologist',
#   'brought',
#   'exploration'],
#  ['oriented',
#   'core',
#   'mark',
#   'bottom',
#   'field',
#   'staff',
#   'assistance',
#   'geologist'],
#  ['piece',
#   'core',
#   'together',
#   'using',
#   'purpose',
#   'built',
#   'angle',
#   'iron',
#   'three',
#   'orientation',
#   'line',
#   'line',
#   'solid'],
#  ['line',
#   'marked',
#   'along',
#   'length',
#   'core',
#   'orientation',
#   'mark',
#   'otherwise'],
#  ['orientation',
#   'mark',
#   'line',
#   'dotted',
#   'line',
#   'drawn',
#   'natural',
#   'break',
#   'drill',
#   'induced',
#   'break'],
#  ['core', 'cannot', 'matched', 'core', 'metre', 'marked', 'using', 'tape'],
#  ['measure',
#   'cross',
#   'referenced',
#   'driller',
#   'measurement',
#   'mark',
#   'core',
#   'block',
#   'inserted'],
#  ['drill', 'core', 'loss', 'natural', 'break', 'fault'],
#  ['recorded', 'geologist', 'grain', 'lithology', 'descriptive'],
#  ['mineral', 'percentage', 'sulphide', 'mineral', 'percentage'],
#  ['magsus', 'data', 'unit', 'collected', 'meter'],
#  ['fugro',
#   'geology',
#   'interval',
#   'logged',
#   'geology',
#   'mineralisation',
#   'core'],
#  ['structurally',
#   'logged',
#   'using',
#   'wrap',
#   'around',
#   'recording',
#   'alpha',
#   'beta',
#   'alpha'],
#  ['beta',
#   'angle',
#   'converted',
#   'using',
#   'micromine',
#   'excel',
#   'data',
#   'entry',
#   'collar',
#   'data'],
#  ['including',
#   'hole',
#   'core',
#   'basement',
#   'intercept',
#   'base',
#   'complete',
#   'oxidation'],
#  ['fresh', 'rock', 'water', 'drill', 'driller', 'data'],
#  ['logged', 'paper', 'entered', 'checked', 'submitted', 'data'],
#  ['exported',
#   'micromine',
#   'diamond',
#   'drill',
#   'core',
#   'stored',
#   'exploration'],
#  ['qaqc'],
#  ['check', 'included', 'submitting', 'duplicate', 'custom', 'crms'],
#  ['every', 'batch', 'genalysis', 'full', 'batch', 'laboratory'],
#  ['performed', 'check', 'according'],
#  ['accreditation'],
#  ['accreditation', 'ensures', 'international', 'standard', 'maintained'],
#  ['reporting', 'record', 'national'],
#  ['association',
#   'testing',
#   'authority',
#   'australia',
#   'accredited',
#   'genalysis',
#   'laboratory',
#   'service'],
#  ['following', 'demonstration', 'technical', 'operate', 'accordance'],
#  ['includes', 'management', 'requirement', 'facility'],
#  ['accredited',
#   'field',
#   'chemical',
#   'testing',
#   'calibration',
#   'measurement',
#   'shown'],
#  ['scope', 'accreditation', 'issued', 'nata'],
#  ['analysis', 'quality', 'control'],
#  ['certified',
#   'reference',
#   'material',
#   'house',
#   'split',
#   'replicates',
#   'analysed'],
#  ['batch', 'quality', 'control', 'result', 'reported', 'along', 'sample'],
#  ['value', 'final'],
#  ['quality',
#   'programme',
#   'includes',
#   'reference',
#   'material',
#   'ideally',
#   'grade'],
#  ['matrix', 'matched', 'diverse', 'number', 'reference', 'material', 'used'],
#  ['regiona', 'geology'],
#  ['mount',
#   'wood',
#   'inlier',
#   'comprises',
#   'high',
#   'grade',
#   'palaeoproterozoic',
#   'metasedimentary',
#   'rock'],
#  ['granulite', 'facies'],
#  ['forsterite', 'intruded'],
#  ['crms',
#   'certified',
#   'reference',
#   'batch',
#   'standard',
#   'prepared',
#   'three',
#   'bulk'],
#  ['sample', 'cairn', 'hill', 'crms', 'prepared', 'gannet', 'holding'],
#  ['perth', 'certified', 'geostats'],
#  ['htplwwigenalysiscomaulanayicallgerneralinomationqualiycortrol'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['post',
#   'tectonic',
#   'granitoids',
#   'balta',
#   'polyphase',
#   'hiltaba',
#   'granite',
#   'equivalent',
#   'comprising'],
#  ['porphyritic', 'granite', 'hybrid', 'covered', 'mesozoic'],
#  ['tertiary',
#   'sedimentary',
#   'metasediments',
#   'characterised',
#   'intense',
#   'magnetic'],
#  ['response',
#   'regional',
#   'aeromagnetic',
#   'reflects',
#   'combination',
#   'magnetite',
#   'rich',
#   'precursor'],
#  ['sediment',
#   'including',
#   'magnetite',
#   'alteration',
#   'probable',
#   'mafic',
#   'intrusive',
#   'inlier'],
#  ['bounded', 'major', 'shear', 'prominent', 'karari', 'fault', 'zone'],
#  ['bound', 'trending', 'coober', 'pedy'],
#  ['snaefell', 'prospect', 'geology', 'structure'],
#  ['snaefell',
#   'prospect',
#   'major',
#   'magnetic',
#   'linear',
#   'feature',
#   'interpreted',
#   'magnetite'],
#  ['rich',
#   'sedimentary',
#   'gneiss',
#   'locally',
#   'rock',
#   'tightly',
#   'folded',
#   'major',
#   'fault'],
#  ['parallel', 'trend', 'snaefell', 'gneiss', 'unit', 'prospect', 'covered'],
#  ['tertiary', 'holocene', 'cover', 'sediment', 'comprising', 'clay'],
#  ['unconsolidated', 'immediately', 'unconformity', 'thick', 'layer', 'highly'],
#  ['weathered', 'ferruginous', 'felsic'],
#  ['highly', 'weathered', 'saprock', 'land', 'surface', 'rock', 'comprises'],
#  ['variably', 'weathered', 'altered', 'smecite'],
#  ['depth', 'magnetite', 'generally', 'undergone', 'degree', 'weathering'],
#  ['evidenced', 'diamond', 'hole', 'within', 'smectite', 'zone'],
#  ['little', 'earthy', 'hematite', 'specular', 'hematite', 'possible'],
#  ['also',
#   'occurs',
#   'magnetite',
#   'notably',
#   'north',
#   'side',
#   'snaefell',
#   'many',
#   'hole',
#   'show'],
#  ['iron', 'grade', 'greater', 'within', 'variability'],
#  ['layered',
#   'sedimentary',
#   'origin',
#   'magnetite',
#   'becomes',
#   'dominate',
#   'iron'],
#  ['figure',
#   'plan',
#   'view',
#   'interpreted',
#   'fault',
#   'drill',
#   'hole',
#   'vertical',
#   'derivative'],
#  ['magnetic', 'image', 'core', 'area', 'snaefell'],
#  ['within', 'gneiss', 'significant', 'marble', 'unit', 'identified', 'traced'],
#  ['section', 'upper', 'marble', 'unit', 'probably', 'facilitated', 'slip'],
#  ['seems', 'caught', 'fault', 'north', 'side'],
#  ['chloritic',
#   'shear',
#   'separate',
#   'underlying',
#   'magnetite',
#   'gneiss',
#   'unit'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['package', 'largely', 'unmineralised', 'felsic', 'gneiss'],
#  ['structural',
#   'information',
#   'show',
#   'foliation',
#   'banding',
#   'appear',
#   'preferred'],
#  ['orientation', 'steeply', 'small', 'scale'],
#  ['asymmetrical', 'fold', 'limb', 'angle', 'form', 'overturned', 'antiforms'],
#  ['steep', 'southern', 'limb', 'northern', 'immediately'],
#  ['gniessic', 'banding', 'dip', 'steepens'],
#  ['approximately', 'drilled', 'south', 'side'],
#  ['snaefell', 'magnetic', 'anomaly', 'core', 'orientation', 'line'],
#  ['steep', 'north', 'structura', 'data', 'core', 'area', 'snaefell'],
#  ['show', 'banding', 'dip', 'north', 'near', 'hanging', 'wall', 'shear'],
#  ['steepens', 'approximate'],
#  ['figure', 'cross', 'section', 'showing', 'structural', 'information'],
#  ['foliation', 'banding', 'coloured', 'banding', 'steepens', 'towards'],
#  ['snaefell', 'conclusion'],
#  ['diamond', 'drill', 'hole', 'drilled', 'tested', 'centre'],
#  ['part', 'snaefell', 'host', 'rock', 'comprise', 'tightly'],
#  ['folded', 'sequence', 'formation', 'magnetite', 'gneiss'],
#  ['subordinate', 'perhaps', 'thickened', 'sequence'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['truncated', 'fault', 'approximately', 'parallel', 'strike', 'orientation'],
#  ['sequence', 'appears', 'parallel', 'main', 'foliation', 'host'],
#  ['dipping', 'steeply', 'north', 'side', 'sequence'],
#  ['appears', 'truncated', 'fault', 'shear', 'parallel', 'trend'],
#  ['petrology',
#   'diamond',
#   'dril',
#   'sample',
#   'indicates',
#   'formation',
#   'metamorphic'],
#  ['metamorphic', 'event', 'greenschist'],
#  ['metamorphic', 'event', 'upper'],
#  ['metamorphic', 'event'],
#  ['metamorphic', 'sediment', 'initial', 'altered', 'greenschist'],
#  ['facies', 'metamorphism', 'gneiss', 'schist', 'magnetite'],
#  ['plagioclase', 'presence', 'scapolite', 'hint', 'precursor', 'evaporite'],
#  ['metamorphic',
#   'event',
#   'possibly',
#   'occurred',
#   'metasomatic',
#   'event',
#   'metamorphism',
#   'oxidation'],
#  ['biotite', 'became', 'magnetite'],
#  ['thereby', 'effectively', 'upgrading', 'primary', 'presence'],
#  ['sample',
#   'indicates',
#   'metamorphism',
#   'continued',
#   'granulite',
#   'facies',
#   'late',
#   'retrograde'],
#  ['metasomatic', 'event', 'potassic', 'alteration', 'formation'],
#  ['pervasive'],
#  ['metallurgy'],
#  ['initial',
#   'davis',
#   'tube',
#   'recovery',
#   'testing',
#   'showed',
#   'magnetite',
#   'gneiss',
#   'running',
#   'could'],
#  ['upgraded',
#   'logging',
#   'diamond',
#   'dril',
#   'hole',
#   'confirmed',
#   'presence',
#   'good'],
#  ['magnetite', 'mineralisation', 'also', 'occurrence', 'mixed', 'iron'],
#  ['earthy', 'hematite', 'magnetite', 'upper', 'weathered', 'zone'],
#  ['earthy', 'hematite', 'specular', 'hematite'],
#  ['specular', 'hematite'],
#  ['identification', 'mixed', 'iron', 'addition'],
#  ['prompted',
#   'detailed',
#   'sighter',
#   'beneficiation',
#   'testwork',
#   'metallurgy',
#   'mixed',
#   'variety'],
#  ['metallurgy', 'result', 'lims', 'magnetic', 'separation'],
#  ['micron', 'could', 'produce', 'magnetite', 'cairn', 'snaefell'],
#  ['magnetite', 'appears', 'relatively', 'potential', 'lower', 'capital'],
#  ['operating', 'cost'],
#  ['tomahawk', 'prospect'],
#  ['tomahawk', 'iron', 'prospect', 'located', 'southeast', 'cairn', 'hill'],
#  ['gold', 'form', 'part', 'wood', 'iron', 'project', 'south', 'prospect'],
#  ['interpreted', 'strike', 'length', 'vertical', 'depth', 'extent'],
#  ['tomahawk',
#   'prospect',
#   'strongest',
#   'magnetic',
#   'feature',
#   'wood',
#   'project',
#   'area'],
#  ['target',
#   'identified',
#   'following',
#   'detailed',
#   'airborne',
#   'geophysica',
#   'survey',
#   'completed'],
#  ['drilling', 'program', 'tested', 'easternmost'],
#  ['corresponds',
#   'intensely',
#   'magnetic',
#   'area',
#   'drilling',
#   'including',
#   'collar'],
#  ['downhole', 'geology', 'survey', 'geological', 'code', 'list', 'presented'],
#  ['appendix'],
#  ['mineralisation',
#   'intersected',
#   'comprises',
#   'layer',
#   'magnetite',
#   'within'],
#  ['part', 'package', 'includes', 'gneiss'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['drilling', 'program', 'november', 'gorey', 'cole'],
#  ['drillers', 'contracted', 'carry', 'program', 'using', 'schram', 'reverse'],
#  ['circulation', 'drill', 'trailer', 'mounted', 'duration', 'program'],
#  ['drill', 'crew', 'geologist', 'field', 'technician', 'accommodated'],
#  ['mineral', 'camp', 'located', 'skylark', 'south', 'east', 'coober'],
#  ['locality'],
#  ['south', 'australia'],
#  ['coober', 'pedy'],
#  ['cairn', 'mine'],
#  ['tomahawk'],
#  ['xolympcd'],
#  ['port'],
#  ['port'],
#  ['adelaide'],
#  ['tomahawk', 'magnetite', 'anomaly'],
#  ['figure', 'location', 'drill', 'hole', 'tomahawk', 'target', 'magnetics'],
#  ['hole', 'location'],
#  ['hole', 'surveyed', 'reflex', 'probe', 'hole'],
#  ['surveyed', 'using', 'north', 'seeking', 'gyro'],
#  ['presence', 'magnetite', 'affecting'],
#  ['geological', 'logging'],
#  ['cone', 'splitter', 'installed', 'beneath', 'attached', 'side', 'performed'],
#  ['split', 'meter', 'producing', 'calico', 'bag', 'larger'],
#  ['presence',
#   'unconsolidated',
#   'hole',
#   'collared',
#   'plastic',
#   'pipe',
#   'depth'],
#  ['sample', 'meter', 'taken', 'larger', 'sieved', 'washed'],
#  ['local',
#   'coober',
#   'pedy',
#   'field',
#   'technician',
#   'logged',
#   'geologist',
#   'chip',
#   'tray'],
#  ['interval', 'used', 'store', 'representative', 'portion', 'sieved'],
#  ['geological',
#   'cross',
#   'section',
#   'showing',
#   'drill',
#   'hole',
#   'significant',
#   'intersection'],
#  ['presented', 'figure'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['figure', 'section', 'tomahawk', 'target', 'drill', 'hole'],
#  ['sampling', 'methodology'],
#  ['niton'],
#  ['starting', 'analysed', 'using', 'thermo', 'scientific', 'niton'],
#  ['analysis', 'performed', 'manually', 'compacted', 'sample', 'taken'],
#  ['centre', 'larger', 'case', 'obviously', 'sample', 'several'],
#  ['performed', 'result'],
#  ['magnetic', 'susceptibility'],
#  ['starting', 'magnetic', 'susceptibility', 'recorded', 'using'],
#  ['magnetic', 'susceptibility', 'metre', 'averaging'],
#  ['geochemical', 'analysis'],
#  ['sample', 'obtained', 'sample'],
#  ['dispatched',
#   'genalysis',
#   'analysis',
#   'analysis',
#   'iron',
#   'extended',
#   'suite'],
#  ['fire', 'assay', 'completed'],
#  ['summary', 'significant', 'interval', 'presented', 'table'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['unconsolidated', 'sediment'],
#  ['carbonate', 'quartz'],
#  ['resource'],
#  ['tomahawk', 'project'],
#  ['interpreter', 'crose', 'section'],
#  ['magnetite', 'quartz'],
#  ['carbonate'],
#  ['azinuee'],
#  ['doto'],
#  ['drawn', 'dforbes'],
#  ['table', 'summary', 'element', 'analysed'],
#  ['element'],
#  ['unit'],
#  ['detection'],
#  ['method'],
#  ['icalc'],
#  ['ical'],
#  ['element'],
#  ['unit'],
#  ['detection'],
#  ['method'],
#  ['icalc'],
#  ['ical'],
#  ['table', 'significant', 'interval', 'tomahawk', 'drilling'],
#  ['hole'],
#  ['interval'],
#  ['including'],
#  ['including'],
#  ['including'],
#  ['including'],
#  ['including'],
#  ['tomahawk', 'summary'],
#  ['conclusion',
#   'initial',
#   'drilling',
#   'tomahawk',
#   'series',
#   'specific',
#   'davis',
#   'tube'],
#  ['recovery', 'sample', 'provided', 'initial', 'insight', 'metallurgical'],
#  ['response',
#   'result',
#   'show',
#   'magnetic',
#   'fraction',
#   'chemistry',
#   'target',
#   'sizing'],
#  ['appropriate', 'initial'],
#  ['result', 'tomahawk', 'prospect', 'hence', 'exploration', 'take', 'place'],
#  ['order',
#   'improve',
#   'confidence',
#   'metallurgica',
#   'response',
#   'along',
#   'potential'],
#  ['size', 'reporting', 'completed', 'neomet', 'presented', 'appendix'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['icalc'],
#  ['total'],
#  ['ical'],
#  ['ical'],
#  ['environment'],
#  ['accordance',
#   'aboriginal',
#   'heritage',
#   'survey',
#   'drill',
#   'hole',
#   'located'],
#  ['creek', 'proximal', 'drilling', 'access', 'drill', 'site'],
#  ['station',
#   'limiting',
#   'damage',
#   'native',
#   'plastic',
#   'calico',
#   'bag',
#   'currently'],
#  ['site', 'collar', 'covered', 'plastic', 'cap', 'limit', 'threat', 'native'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['summary', 'rfhabilitation', 'activity'],
#  ['hole'],
#  ['backfilled',
#   'abandoned',
#   'according',
#   'guideline',
#   'given',
#   'pirsa',
#   'information',
#   'sheet'],
#  ['plan',
#   'submit',
#   'series',
#   'bulk',
#   'sample',
#   'snaefell',
#   'prospect',
#   'metallurgical',
#   'testwork'],
#  ['sample',
#   'bag',
#   'remain',
#   'representative',
#   'image',
#   'site',
#   'showing',
#   'rehab',
#   'work'],
#  ['completed', 'shown', 'figure', 'rehabilitation', 'status', 'drill', 'hole'],
#  ['summarized', 'table'],
#  ['figure', 'snaefell', 'july', 'diamond', 'hole', 'plastic', 'liner'],
#  ['sump'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['figure', 'snaefell', 'july', 'hole', 'hole'],
#  ['still'],
#  ['figure', 'hole'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['figure', 'hole', 'rehabilitation'],
#  ['rehabilitation', 'work', 'described', 'chai', 'hodgson'],
#  ['preparation', 'shallow', 'sump', 'deep'],
#  ['backhoe',
#   'loader',
#   'next',
#   'hole',
#   'contain',
#   'potential',
#   'saline',
#   'ground',
#   'water'],
#  ['encountered',
#   'drilling',
#   'well',
#   'water',
#   'pumped',
#   'recirculated',
#   'hole'],
#  ['course', 'diamond', 'drill', 'hole', 'sump', 'lined'],
#  ['plastic'],
#  ['completion', 'plastic', 'liner', 'removed', 'disposed', 'sump', 'filled'],
#  ['area', 'covered', 'original'],
#  ['drill', 'site', 'rubbish', 'sump', 'necessary'],
#  ['surface',
#   'scarified',
#   'snaefell',
#   'plan',
#   'submit',
#   'metallurgical',
#   'testwork',
#   'series',
#   'bulk'],
#  ['sample',
#   'green',
#   'plastic',
#   'bag',
#   'containing',
#   'drill',
#   'currently',
#   'remain'],
#  ['respective', 'bag', 'take', 'time', 'agreed', 'periodically'],
#  ['green', 'plastic'],
#  ['prospect',
#   'lie',
#   'within',
#   'coober',
#   'pedy',
#   'precious',
#   'mineral',
#   'condition'],
#  ['requires', 'sample', 'hole', 'collected', 'submitted', 'pirsa'],
#  ['coober', 'material', 'collected', 'green'],
#  ['summary', 'combined', 'drilling', 'rehabilitation', 'activites'],
#  ['january', 'combined', 'wood', 'report'],
#  ['resource'],
#  ['annual', 'report', 'period', 'january', 'january'],
#  ['table', 'snaefell', 'rehabilitated', 'site'],
#  ['hole'],
#  ['hole'],
#  ['prospect'],
#  ['type'],
#  ['east'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ['snaefell'],
#  ...]

# %%
lines = new_lines

# %%
#importing the glove library
from glove import Corpus, Glove
# creating a corpus object
corpus = Corpus() 
#training the corpus to generate the co occurence matrix which is used in GloVe
corpus.fit(lines, window=10)
#creating a Glove object which will use the matrix created in the above lines to create embeddings
#We can set the learning rate as it uses Gradient Descent and number of components
glove = Glove(no_components=300, learning_rate=0.05)
 
glove.fit(corpus.matrix, epochs=30, no_threads=4, verbose=True)
glove.add_dictionary(corpus.dictionary)
glove.save('glove.model')
# Out:
# Performing 30 training epochs with 4 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19
# Epoch 20
# Epoch 21
# Epoch 22
# Epoch 23
# Epoch 24
# Epoch 25
# Epoch 26
# Epoch 27
# Epoch 28
# Epoch 29

# %%
print (glove.word_vectors[glove.dictionary['geology']])
# Out:
# [-3.90742791e-02 -4.88191720e-02 -2.08157959e-02 -1.02684108e-01
#  -5.93699050e-02 -9.18336882e-02 -2.53752306e-02  7.69795971e-02
#  -7.54103997e-02  2.21496115e-02  1.88776102e-02 -5.07945496e-02
#   1.44395514e-02 -8.90376246e-03 -1.87745868e-02  5.60825770e-02
#   1.83077811e-02 -4.21780621e-02  4.57614594e-02  7.03468330e-02
#   9.07849109e-03 -8.87160733e-02  7.48548158e-02  8.13032398e-03
#   3.91406991e-02 -1.21055950e-02  9.90533522e-02 -7.39836482e-02
#   4.41942635e-02 -2.65177855e-02 -3.06982178e-02  5.95603622e-02
#  -1.62499660e-02 -8.32650540e-03  6.48746027e-03  1.26120844e-02
#  -1.95289205e-02 -2.33897507e-02  5.02395193e-02 -1.06815405e-02
#  -4.82906059e-02  1.30140516e-01 -3.60404512e-02  1.78375327e-02
#   1.33555611e-02 -6.56101174e-02  8.08314454e-04 -6.54275545e-02
#  -5.26638514e-02  3.68457038e-02 -5.74796742e-02  3.08823604e-02
#   7.43918079e-02  1.86959608e-03  6.30738328e-02 -1.02600239e-01
#  -2.43113084e-02 -4.22259300e-02 -5.00903704e-02  6.70469871e-04
#  -3.60504008e-02 -1.67554481e-03  7.10968955e-02  8.48890470e-02
#  -2.89039111e-02  2.74584503e-02 -1.01864110e-01  1.36492797e-02
#   5.36731862e-05  5.50826820e-02 -8.08243571e-02  8.16751163e-03
#   1.46562167e-02 -4.25956597e-02  1.39486705e-02 -1.98226203e-02
#   6.93506570e-02  3.30147673e-02 -7.52953270e-02 -1.47637612e-02
#   4.24561745e-02 -2.72110585e-02 -4.29503837e-02 -6.57978011e-02
#   1.04715885e-01 -7.59123435e-03  4.23747595e-02  2.92194982e-02
#  -5.50957371e-02  1.93895945e-01  5.01773995e-02 -4.16859065e-02
#   2.98195408e-02 -2.14898089e-02 -4.89069514e-02 -1.52759216e-02
#  -1.57863350e-03  3.29714122e-02 -6.82666747e-02 -8.13804711e-02
#   9.20523418e-02 -4.76908598e-02  5.85615755e-02 -5.64248287e-02
#   1.69978810e-02  1.66334025e-02 -2.47969806e-02 -5.06681454e-02
#   2.95613634e-02 -5.95966049e-02 -1.36174182e-02 -6.57127070e-02
#  -1.34602367e-02 -8.34264463e-02 -4.61244990e-02  1.46346024e-02
#   6.68513086e-02 -2.21634872e-02  7.19114664e-03  4.44132690e-02
#  -1.51957599e-02  2.47128229e-02  1.66581821e-02  1.17054737e-01
#   4.46489635e-02 -1.00391990e-01  8.19571068e-02 -8.78138714e-02
#   8.85901565e-03 -9.20808083e-03 -3.12437530e-02  6.59479409e-02
#  -8.89729083e-03  1.43961517e-02  3.86951547e-02 -6.41101030e-03
#  -4.94329111e-02 -2.14682311e-02 -6.33158976e-03 -1.15475015e-01
#  -6.97869685e-03  7.97773682e-02 -7.17450169e-03  6.46800359e-03
#  -2.54620339e-02 -2.86327220e-02  9.58255327e-03  4.15283460e-02
#  -3.62511031e-03  3.46493674e-02  2.31238109e-02 -7.83971828e-02
#  -4.60401907e-02  7.26019316e-02 -1.37409768e-02  5.07988789e-02
#   5.11033813e-02 -6.30177793e-02 -5.76688335e-02  2.85956593e-02
#   3.24013159e-02 -1.21594764e-01  7.17760733e-03  1.87775230e-02
#  -1.11514346e-02  4.72746332e-02  9.60465566e-02 -4.99384471e-02
#   5.21660055e-02 -2.77350086e-02  3.90994919e-02  3.15447952e-02
#   8.24646598e-02  1.12797392e-02  2.62986321e-02 -5.70113032e-02
#  -4.05147246e-02 -8.28998766e-02  5.14239639e-03  3.43780230e-02
#  -6.75546293e-02 -6.78231083e-03  1.62386378e-02  3.36527267e-02
#   8.79514292e-02 -3.77980938e-02 -6.86533731e-04  4.31257875e-03
#   1.69163779e-02 -4.66139116e-02  7.79803985e-02  7.64970475e-02
#   4.41525257e-02  2.81290691e-02 -2.27522121e-02  5.03882108e-02
#   3.84936483e-02 -1.91618323e-02 -1.25169864e-02  3.41265671e-02
#  -1.14716784e-02  2.07469242e-02  8.77781162e-03 -4.65949465e-02
#   2.95050985e-02  5.22351889e-02 -4.13290893e-02  3.26238976e-02
#  -3.71021930e-04 -7.01239242e-02  3.50908047e-02 -2.32138162e-02
#  -9.45211574e-02 -5.87005708e-02 -8.66479394e-02  4.24360848e-02
#   5.41437616e-02 -4.73932197e-02  3.13336604e-02  4.23917489e-02
#  -1.01028839e-01 -1.48804738e-02  6.71994355e-02 -4.43592307e-02
#  -8.71389794e-02  9.41077264e-03 -1.13836489e-01 -9.79256369e-02
#  -6.71109573e-03 -7.74958140e-02  5.75592562e-02  7.20285887e-02
#   5.67999612e-03  3.91502600e-02 -1.25622137e-01 -7.01206943e-02
#   4.39252829e-02  1.35918201e-02 -6.53524591e-02  3.67284084e-02
#  -5.14808660e-02 -5.70781432e-02  3.88696000e-02  2.34064203e-03
#   7.27996693e-02 -3.67227472e-02  3.45758823e-02  8.13222773e-02
#   8.67497726e-03 -3.00939888e-02  6.81831330e-02  4.13726772e-03
#   4.99777247e-02 -6.84555731e-02 -3.99172156e-02 -8.35188710e-02
#   5.75869396e-02 -3.77207843e-02 -5.96197333e-03  3.29341047e-02
#   3.72563271e-02  5.78751298e-02 -2.81647416e-02  7.56255634e-02
#  -3.24733664e-04  2.22746963e-02 -2.03154619e-02  5.77597878e-02
#   2.87934135e-02  1.98617980e-02  2.21111959e-03 -2.86712020e-02
#  -3.90989330e-03 -2.73699426e-02 -3.04033942e-02 -9.18207202e-03
#   2.62227246e-03 -6.61230231e-02  1.19615300e-01 -4.00597124e-03
#  -6.09402578e-02  1.44089540e-02 -3.43288171e-02 -4.28915947e-02
#  -9.64979779e-02  1.54051494e-02  4.60932361e-02 -1.33617573e-02
#   2.85411578e-02  6.81073435e-02  1.18450255e-01 -2.30772861e-02
#   3.93775868e-02  5.71928335e-02  3.50308107e-02  4.86696284e-02
#   6.62605867e-03 -4.41420192e-02 -8.47360881e-02 -1.68106553e-01]

# %%
len(glove.dictionary)
# Out:
# 12474

# %%
glove.word_vectors.shape
# Out:
# (12474, 300)

# %%
glove.word_vectors
# Out:
# array([[ 1.17716655e-01,  2.10166135e-02,  2.38329837e-02, ...,
#         -2.38326603e-02, -3.82835928e-02, -2.66947804e-01],
#        [ 2.36871208e-02, -4.03296789e-02,  8.65568234e-03, ...,
#         -3.66723008e-02,  3.48927676e-02,  1.10181203e-02],
#        [ 3.06087746e-02, -9.87595897e-02,  8.20647615e-02, ...,
#         -1.70518830e-01, -3.75247209e-02,  8.75876482e-02],
#        ...,
#        [ 1.56301980e-03,  1.13722570e-03, -1.58378401e-03, ...,
#         -1.16589166e-03, -1.57410782e-03, -1.56664188e-03],
#        [ 6.35767858e-04,  1.37842607e-03,  7.42542560e-04, ...,
#          2.30141192e-03, -1.48169410e-03,  1.87929749e-03],
#        [-4.16485612e-05,  1.91399336e-03,  1.54990048e-03, ...,
#          6.59866878e-04,  2.33992404e-03,  3.26948506e-04]])

# %%
glove.most_similar('magnetics')
# Out:
# [('italy', 0.9813728736074101),
#  ('electro', 0.9543653176955708),
#  ('fugro', 0.9143021448926846),
#  ('aerial', 0.7333054810051206)]
