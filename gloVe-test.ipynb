# %%
#import glove
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
#import nltk 
#nltk.download() 
#!pip install glove-python-binary  thanks to @Ironwolf on github
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
lines=["Hello this is a tutorial on how to convert the word in an integer format", "this is a beautiful day","Jack is going to office"]
target_url='https://mer-env.s3-ap-southeast-2.amazonaws.com/ENV12248.pdf-textract-text.txt'
import urllib.request
data = urllib.request.urlopen(target_url)
lines = []
for line in data:    
    #print(line.decode('utf-8'))
    lines.append(line.decode('utf-8').lower())

# %%
lines2 = lines.copy()

# %%
stop_words=set(stopwords.words('english')) 
lines_without_stopwords=[] #stop words contain the set of stop words 
for line in lines: 
    splitline = line.split(' ')
    #print(splitline)
    #break
    #print(splitline)
    #break
    temp_line=[] 
    for word in splitline: 
        #print(word)
        if word not in stop_words: 
            temp_line.append(word) 
            string=' ' 
    lines_without_stopwords.append(string.join(temp_line)) 
    
lines=lines_without_stopwords

# %%
print(len(lines))
lines
# Out:
# 240578
# ['imx\r\n',
#  'resources\r\n',
#  'combined annual report\r\n',
#  'mount woods jv project\r\n',
#  'period\r\n',
#  '1st february 2011 31st january 2012\r\n',
#  'el3729, el3730, el3830, el4446, el4706, el4649\r\n',
#  'holder/ operator:\r\n',
#  'imx resources ltd\r\n',
#  'level 2, 100 railway road\r\n',
#  'subiaco wa 6008\r\n',
#  'oz minerals ltd\r\n',
#  '170 greenhill road,\r\n',
#  'parkside sa 5063\r\n',
#  'lynch (imx), c rochat, damm harris\r\n',
#  '(oz)\r\n',
#  'tammi doyle yvette laubsch\r\n',
#  'march 2012\r\n',
#  'pirsa - (1 digital)\r\n',
#  'imx resources ltd - (1 digital, 1 hardcopy)\r\n',
#  'oz minerals ltd - (1 digital, 1 hardcopy)\r\n',
#  'report contents confidential. rights report contents (including, without limitation, rights confidential\r\n',
#  'information copy right works (including photographs, diagrams, charts, maps graphs) comprised report) remain property\r\n',
# ...

# %%
#import WordNet Lemmatizer from nltk 

wordnet_lemmatizer = WordNetLemmatizer() 
lines_with_lemmas=[] 
#stop words contain the set of stop words 
for line in lines:
    splitline = line.split(' ')
    temp_line=[] 
    for word in splitline: 
        #print(wordnet_lemmatizer.lemmatize(word))
        temp_line.append(wordnet_lemmatizer.lemmatize(word)) 
        string=' ' 
    lines_with_lemmas.append(string.join(temp_line)) 
        
lines=lines_with_lemmas

# %%
print(len(lines_with_lemmas))
lines_with_lemmas
# Out:
# 240578
# ['imx\r\n',
#  'resources\r\n',
#  'combined annual report\r\n',
#  'mount wood jv project\r\n',
#  'period\r\n',
#  '1st february 2011 31st january 2012\r\n',
#  'el3729, el3730, el3830, el4446, el4706, el4649\r\n',
#  'holder/ operator:\r\n',
#  'imx resource ltd\r\n',
#  'level 2, 100 railway road\r\n',
#  'subiaco wa 6008\r\n',
#  'oz mineral ltd\r\n',
#  '170 greenhill road,\r\n',
#  'parkside sa 5063\r\n',
#  'lynch (imx), c rochat, damm harris\r\n',
#  '(oz)\r\n',
#  'tammi doyle yvette laubsch\r\n',
#  'march 2012\r\n',
#  'pirsa - (1 digital)\r\n',
#  'imx resource ltd - (1 digital, 1 hardcopy)\r\n',
#  'oz mineral ltd - (1 digital, 1 hardcopy)\r\n',
#  'report content confidential. right report content (including, without limitation, right confidential\r\n',
#  'information copy right work (including photographs, diagrams, charts, map graphs) comprised report) remain property\r\n',
# ...

# %%
new_lines=[] 
for line in lines: 
    splitline=line.split(' ') #new lines has the new format lines=new_lines
    new_lines.append(splitline)

# %%
new_lines
# Out:
# [['imx\r\n'],
#  ['resources\r\n'],
#  ['combined', 'annual', 'report\r\n'],
#  ['mount', 'wood', 'jv', 'project\r\n'],
#  ['period\r\n'],
#  ['1st', 'february', '2011', '31st', 'january', '2012\r\n'],
#  ['el3729,', 'el3730,', 'el3830,', 'el4446,', 'el4706,', 'el4649\r\n'],
#  ['holder/', 'operator:\r\n'],
#  ['imx', 'resource', 'ltd\r\n'],
#  ['level', '2,', '100', 'railway', 'road\r\n'],
#  ['subiaco', 'wa', '6008\r\n'],
#  ['oz', 'mineral', 'ltd\r\n'],
#  ['170', 'greenhill', 'road,\r\n'],
#  ['parkside', 'sa', '5063\r\n'],
#  ['lynch', '(imx),', 'c', 'rochat,', 'damm', 'harris\r\n'],
#  ['(oz)\r\n'],
#  ['tammi', 'doyle', 'yvette', 'laubsch\r\n'],
#  ['march', '2012\r\n'],
#  ['pirsa', '-', '(1', 'digital)\r\n'],
#  ['imx', 'resource', 'ltd', '-', '(1', 'digital,', '1', 'hardcopy)\r\n'],
#  ['oz', 'mineral', 'ltd', '-', '(1', 'digital,', '1', 'hardcopy)\r\n'],
#  ['report',
#   'content',
#   'confidential.',
#   'right',
#   'report',
#   'content',
#   '(including,',
# ...

# %%
lines = new_lines

# %%
#importing the glove library
#from glove import Glove
from glove import Corpus, Glove
# creating a corpus object
corpus = glove.Corpus() 
#training the corpus to generate the co occurence matrix which is used in GloVe
corpus.fit(lines, window=10)
#creating a Glove object which will use the matrix created in the above lines to create embeddings
#We can set the learning rate as it uses Gradient Descent and number of components
glove = Glove(no_components=5, learning_rate=0.05)
 
glove.fit(corpus.matrix, epochs=30, no_threads=4, verbose=True)
glove.add_dictionary(corpus.dictionary)
glove.save('glove.model')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2024904eae59> in <module>
#       3 from glove import Corpus, Glove
#       4 # creating a corpus object
# ----> 5 corpus = glove.Corpus()
#       6 #training the corpus to generate the co occurence matrix which is used in GloVe
#       7 corpus.fit(lines, window=10)
#
# NameError: name 'glove' is not defined

# %%
print (glove.word_vectors[glove.dictionary['tutorial']])
# Out:
# [-0.02752881 -0.03379031  0.03393317 -0.02772145 -0.07067223]

# %%
glove.dictionary
# Out:
# {'Hello': 0,
#  'tutorial': 1,
#  'convert': 2,
#  'word': 3,
#  'integer': 4,
#  'format': 5,
#  'beautiful': 6,
#  'day': 7,
#  'Jack': 8,
#  'going': 9,
#  'office': 10}

# %%
target_url='https://mer-env.s3-ap-southeast-2.amazonaws.com/ENV12248.pdf-textract-text.txt'
import urllib.request
data = urllib.request.urlopen(target_url)
lines = []
for line in data:    
    #print(line.decode('utf-8'))
    lines.append(line.decode('utf-8').lower())

# %%
len(lines)
# Out:
# 240578
